# %% [markdown]
# ##  A Quick Review from W1

# %% [markdown]
# Before pulling any data, we've gotta import all the packages we need

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Now we can read in the data from a link OR from a file in the same directory

# %%
movies = pd.read_csv('imdb.csv')

# %% [markdown]
# Take a quick look at the data

# %%
movies.head(3)
# Out:
#                                  movie_title  imdb_score content_rating  \
# 0                                    Avatar          7.9          PG-13
# 1  Pirates of the Caribbean: At World's End          7.1          PG-13
# 2                                   Spectre          6.8          PG-13
#
#         budget        gross  duration                           genres  \
# 0  237000000.0  760505847.0     178.0  Action|Adventure|Fantasy|Sci-Fi
# 1  300000000.0  309404152.0     169.0         Action|Adventure|Fantasy
# 2  245000000.0  200074175.0     148.0        Action|Adventure|Thriller
#
#       actor_1_name      actor_2_name      actor_3_name   director_name  \
# 0      CCH Pounder  Joel David Moore         Wes Studi   James Cameron
# 1      Johnny Depp     Orlando Bloom    Jack Davenport  Gore Verbinski
# 2  Christoph Waltz      Rory Kinnear  Stephanie Sigman      Sam Mendes
#
#   language country  aspect_ratio  title_year
# 0  English     USA          1.78      2009.0
# 1  English     USA          2.35      2007.0
# 2  English      UK          2.35      2015.0

# %% [markdown]
# How many rows are there? Columns?

# %%
movies.shape
# Out:
# (5043, 15)

# %% [markdown]
# There's a lot of columns, could we get a full list?

# %%
movies.columns.values.tolist()
# Out:
# ['movie_title',
#  'imdb_score',
#  'content_rating',
#  'budget',
#  'gross',
#  'duration',
#  'genres',
#  'actor_1_name',
#  'actor_2_name',
#  'actor_3_name',
#  'director_name',
#  'language',
#  'country',
#  'aspect_ratio',
#  'title_year']

# %% [markdown]
# # Pandas Foundations

# %% [markdown]
# ## Dataframe who?

# %% [markdown]
# Think of dataframes as little "spreadsheets" that hold our data.
# <br>Each row represents an observation, and each column represents some feature about that data.
#
# <br> With little bits of code, we can modify what that spreadsheet looks like.
# <br> For example, our raw data `movies` can be transformed to show some metric about some feature for some subset of the data

# %%
# For example:
movies[movies.country.isin(['USA','France','UK'])].groupby('country')[['gross', 'budget']].agg(['median','max'])
# Out:
#               gross                   budget
#              median          max      median          max
# country
# France    4291965.0  145000989.0  19715000.0  390000000.0
# UK       13401683.0  362645141.0  15000000.0  250000000.0
# USA      32178777.0  760505847.0  20000000.0  300000000.0

# %% [markdown]
# ## Series vs. Dataframes

# %% [markdown]
# We've been referring to *2 dimensional* tables using the `pd.DataFrame` object
# <br>An individual column (or row), is *1 dimensional*. We call this a `pd.Series` object

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# We can access a series (always 1-dimensional) using either: `df.column` OR `df['column']`

# %%
print(type(movies.imdb_score))
print(movies.imdb_score)
# Out:
# <class 'pandas.core.series.Series'>
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 5038    7.7
# 5039    7.5
# 5040    6.3
# 5041    6.3
# 5042    6.6
# Name: imdb_score, Length: 5043, dtype: float64

# %%
print(type(movies['imdb_score']))
print(movies['imdb_score'])
# Out:
# <class 'pandas.core.series.Series'>
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 5038    7.7
# 5039    7.5
# 5040    6.3
# 5041    6.3
# 5042    6.6
# Name: imdb_score, Length: 5043, dtype: float64

# %% [markdown]
# To select a **row** as a series, we can use `df.iloc[]` and a specific row number (its index)

# %%
print(type(movies.iloc[3]))
movies.iloc[3]
# Out:
# <class 'pandas.core.series.Series'>
# movie_title       The Dark Knight Rises
# imdb_score                           8.5
# content_rating                     PG-13
# budget                           2.5e+08
# gross                        4.48131e+08
# duration                             164
# genres                   Action|Thriller
# actor_1_name                   Tom Hardy
# actor_2_name              Christian Bale
# actor_3_name        Joseph Gordon-Levitt
# director_name          Christopher Nolan
# language                         English
# country                              USA
# aspect_ratio                        2.35
# title_year                          2012
# Name: 3, dtype: object

# %% [markdown]
# ## Subsetting Columns

# %% [markdown]
# Subsetting and filtering is one of the most important, yet confusing topics when getting started.
# <br>As we go along, feel free to run the code part by part to see what's going on in each step. `type()` is also a great tool here

# %% [markdown]
# Lets take a look at a smaller set of columns, say the movie title, actors & director name

# %%
movies[['movie_title','actor_1_name','actor_2_name','actor_3_name','director_name']] # Note TWO square brackets
# Out:
#                                             movie_title     actor_1_name  \
# 0                                               Avatar       CCH Pounder
# 1             Pirates of the Caribbean: At World's End       Johnny Depp
# 2                                              Spectre   Christoph Waltz
# 3                                The Dark Knight Rises         Tom Hardy
# 4     Star Wars: Episode VII - The Force Awakens    ...      Doug Walker
# ...                                                 ...              ...
# 5038                           Signed Sealed Delivered       Eric Mabius
# 5039                         The Following                   Natalie Zea
# 5040                              A Plague So Pleasant       Eva Boehnke
# 5041                                  Shanghai Calling         Alan Ruck
# 5042                                 My Date with Drew       John August
#
#           actor_2_name          actor_3_name      director_name
# 0     Joel David Moore             Wes Studi      James Cameron
# 1        Orlando Bloom        Jack Davenport     Gore Verbinski
# 2         Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3       Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4           Rob Walker                   NaN        Doug Walker
# ...                ...                   ...                ...
# 5038     Daphne Zuniga          Crystal Lowe        Scott Smith
# 5039     Valorie Curry         Sam Underwood                NaN
# 5040     Maxwell Moody        David Chandler   Benjamin Roberds
# 5041     Daniel Henney           Eliza Coupe        Daniel Hsia
# 5042  Brian Herzlinger              Jon Gunn           Jon Gunn
#
# [5043 rows x 5 columns]

# %% [markdown]
# Side Note: Why did we use two square brackets? What we're doing is passing a `list` to the subset function.
# <br> Pandas `DataFrame` objects know that whenever we place `[]` after it, we're looking to do some sort of filtering operation

# %%
actor_cols = ['actor_1_name','actor_2_name','actor_3_name']
movies[actor_cols]
# Out:
#          actor_1_name      actor_2_name          actor_3_name
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 5038      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 5039      Natalie Zea     Valorie Curry         Sam Underwood
# 5040      Eva Boehnke     Maxwell Moody        David Chandler
# 5041        Alan Ruck     Daniel Henney           Eliza Coupe
# 5042      John August  Brian Herzlinger              Jon Gunn
#
# [5043 rows x 3 columns]

# %% [markdown]
# Another quick point of confusion: Check out the difference between `df['column']` vs `df[['column']]` ( try it out below)

# %%
movies['content_rating']
# Out:
# 0       PG-13
# 1       PG-13
# 2       PG-13
# 3       PG-13
# 4         NaN
#         ...
# 5038      NaN
# 5039    TV-14
# 5040      NaN
# 5041    PG-13
# 5042       PG
# Name: content_rating, Length: 5043, dtype: object

# %%
movies[['content_rating']]
# Out:
#      content_rating
# 0             PG-13
# 1             PG-13
# 2             PG-13
# 3             PG-13
# 4               NaN
# ...             ...
# 5038            NaN
# 5039          TV-14
# 5040            NaN
# 5041          PG-13
# 5042             PG
#
# [5043 rows x 1 columns]

# %% [markdown]
# The former creates a *series*, since the input is just one *string*. The latter creates a *dataframe*, since the input is a *list* of columns.

# %% [markdown]
# ## Filtering Rows With Conditions

# %% [markdown]
# Another common task is to filter rows based upon some criteria we have. We could:
# 1. Compare floats
# 2. Match strings
# 3. Check against multiple elements

# %%
movies[movies.imdb_score > 8]
# Out:
#                                  movie_title  imdb_score content_rating  \
# 3                     The Dark Knight Rises          8.5          PG-13
# 17                             The Avengers          8.1          PG-13
# 27               Captain America: Civil War          8.2          PG-13
# 43                              Toy Story 3          8.3              G
# 58                                   WALL·E          8.4              G
# ...                                      ...         ...            ...
# 4924                         Butterfly Girl          8.7            NaN
# 4937              A Charlie Brown Christmas          8.4           TV-G
# 4945                   The Brain That Sings          8.2            NaN
# 4972  Peace, Propaganda & the Promised Land          8.3            NaN
# 5001                         The Last Waltz          8.2             PG
#
#            budget        gross  duration  \
# 3     250000000.0  448130642.0     164.0
# 17    220000000.0  623279547.0     173.0
# 27    250000000.0  407197282.0     147.0
# 43    200000000.0  414984497.0     103.0
# 58    180000000.0  223806889.0      98.0
# ...           ...          ...       ...
# 4924     180000.0          NaN      78.0
# 4937     150000.0          NaN      25.0
# 4945     125000.0          NaN      62.0
# 4972      70000.0          NaN      80.0
# 5001          NaN     321952.0     117.0
#
#                                          genres       actor_1_name  \
# 3                               Action|Thriller          Tom Hardy
# 17                      Action|Adventure|Sci-Fi    Chris Hemsworth
# 27                      Action|Adventure|Sci-Fi  Robert Downey Jr.
# 43    Adventure|Animation|Comedy|Family|Fantasy          Tom Hanks
# 58            Adventure|Animation|Family|Sci-Fi  John Ratzenberger
# ...                                         ...                ...
# 4924                                Documentary      Abigail Evans
# 4937                    Animation|Comedy|Family      Peter Robbins
# 4945                         Documentary|Family                NaN
# 4972                                Documentary       Noam Chomsky
# 5001                          Documentary|Music        Ringo Starr
#
#             actor_2_name          actor_3_name      director_name language  \
# 3         Christian Bale  Joseph Gordon-Levitt  Christopher Nolan  English
# 17     Robert Downey Jr.    Scarlett Johansson        Joss Whedon  English
# 27    Scarlett Johansson           Chris Evans      Anthony Russo  English
# 43     John Ratzenberger           Don Rickles        Lee Unkrich  English
# 58          Fred Willard           Jeff Garlin     Andrew Stanton  English
# ...                  ...                   ...                ...      ...
# 4924        Stacie Evans          Emily Gorell          Cary Bell  English
# 4937       Bill Melendez      Christopher Shea      Bill Melendez  English
# 4945                 NaN                   NaN    Amal Al-Agroobi   Arabic
# 4972       Seth Ackerman        Arik Ascherman         Sut Jhally  English
# 5001          Levon Helm             Bob Dylan    Martin Scorsese  English
#
#                    country  aspect_ratio  title_year
# 3                      USA          2.35      2012.0
# 17                     USA          1.85      2012.0
# 27                     USA          2.35      2016.0
# 43                     USA          1.85      2010.0
# 58                     USA          2.35      2008.0
# ...                    ...           ...         ...
# 4924                   USA           NaN      2014.0
# 4937                   USA          1.33      1965.0
# 4945  United Arab Emirates           NaN      2013.0
# 4972                   USA           NaN      2004.0
# 5001                   USA          1.85      1978.0
#
# [253 rows x 15 columns]

# %%
movies[movies.content_rating == 'G']
# Out:
#                                             movie_title  imdb_score  \
# 35                                 Monsters University          7.3
# 41                                              Cars 2          6.3
# 43                                         Toy Story 3          8.3
# 58                                              WALL·E          8.4
# 91                                   The Polar Express          6.6
# 119                                        Ratatouille          8.0
# 209                                              Rio 2          6.4
# 238                                     Monsters, Inc.          8.1
# 277                          The Princess and the Frog          7.1
# 297                        The Hunchback of Notre Dame          6.9
# 298                           The Emperor's New Groove          7.3
# 323                                  The Peanuts Movie          7.2
# 338                                       Finding Nemo          8.2
# 353                                        Toy Story 2          7.9
# 362                                              Mulan          7.5
# 384                                                Rio          7.0
# 406                                     102 Dalmatians          4.8
# 444                                    Charlotte's Web          6.4
# 448               Alvin and the Chipmunks: Chipwrecked          4.4
# 473                   Spirit: Stallion of the Cimarron          7.0
# 480                                      Fantasia 2000          7.3
# 500                              Babe: Pig in the City          5.8
# 504                                             Oceans          7.8
# 509                                      The Lion King          8.5
# 583                                               Cars          7.2
# 657                                 The Santa Clause 2          5.5
# 714                                     Chicken Little          5.8
# 756                             The Tale of Despereaux          6.1
# 839                                         Pocahontas          6.6
# 902                                          Anastasia          7.1
# ...                                                 ...         ...
# 2913                              The Land Before Time          7.3
# 2943                        The Muppet Christmas Carol          7.7
# 3028                High School Musical 3: Senior Year          4.5
# 3079                             2001: A Space Odyssey          8.3
# 3101                                   The Longest Day          7.8
# 3107                                           Oliver!          7.5
# 3109                              Recess: School's Out          6.5
# 3142                   Kit Kittredge: An American Girl          6.7
# 3179                                The Straight Story          8.0
# 3280                               Fiddler on the Roof          8.0
# 3356                                  The Muppet Movie          7.7
# 3359                                The Sound of Music          8.0
# 3518                                   The Mighty Macs          6.5
# 3563                              The Andromeda Strain          7.2
# 3708                    The Return of the Pink Panther          7.1
# 3723                                  Doug's 1st Movie          5.0
# 3970                                Gone with the Wind          8.2
# 4024                             March of the Penguins          7.6
# 4062                    Beneath the Planet of the Apes          6.1
# 4064                              Pokémon 3: The Movie          5.6
# 4093               Willy Wonka & the Chocolate Factory          7.8
# 4162                                The Black Stallion          7.4
# 4185                Escape from the Planet of the Apes          6.3
# 4225                                          Fantasia          7.8
# 4362                 Battle for the Planet of the Apes          5.5
# 4427                                      Modern Times          8.6
# 4591                              A Lego Brickumentary          6.8
# 4725                                             Benji          6.1
# 4787  Rise of the Entrepreneur: The Search for a Bet...         8.2
# 4874                             Sunday School Musical          2.5
#
#      content_rating       budget        gross  duration  \
# 35                G  200000000.0  268488329.0     104.0
# 41                G  200000000.0  191450875.0     106.0
# 43                G  200000000.0  414984497.0     103.0
# 58                G  180000000.0  223806889.0      98.0
# 91                G  165000000.0     665426.0     100.0
# 119               G  150000000.0  206435493.0     111.0
# 209               G  103000000.0  131536019.0     101.0
# 238               G  115000000.0  289907418.0      92.0
# 277               G  105000000.0  104374107.0      97.0
# 297               G  100000000.0  100117603.0      91.0
# 298               G  100000000.0   89296573.0      78.0
# 323               G   99000000.0  130174897.0      88.0
# 338               G   94000000.0  380838870.0     100.0
# 353               G   90000000.0  245823397.0      82.0
# 362               G   90000000.0  120618403.0      88.0
# 384               G   90000000.0  143618384.0      96.0
# 406               G   85000000.0   66941559.0     100.0
# 444               G          NaN   82506325.0      97.0
# 448               G   75000000.0  133103929.0      87.0
# 473               G   80000000.0   73215310.0      83.0
# 480               G   80000000.0   60507228.0      74.0
# 500               G   80000000.0   18318000.0      97.0
# 504               G   40000000.0   19406406.0     104.0
# 509               G   45000000.0  422783777.0      73.0
# 583               G  120000000.0  244052771.0     117.0
# 657               G   60000000.0  139225854.0     104.0
# 714               G  150000000.0  135381507.0      81.0
# 756               G   60000000.0   50818750.0      93.0
# 839               G   55000000.0  141600000.0      84.0
# 902               G   50000000.0   58297830.0      94.0
# ...             ...          ...          ...       ...
# 2913              G   12500000.0   48092846.0      69.0
# 2943              G   12000000.0   27281507.0      89.0
# 3028              G   11000000.0   90556401.0     112.0
# 3079              G   12000000.0   56715371.0     161.0
# 3101              G   10000000.0          NaN     178.0
# 3107              G   10000000.0   16800000.0     153.0
# 3109              G   23000000.0   36696761.0      82.0
# 3142              G   10000000.0   17655201.0     101.0
# 3179              G   10000000.0    6197866.0     112.0
# 3280              G    9000000.0   50000000.0     181.0
# 3356              G          NaN   76657000.0      95.0
# 3359              G    8200000.0  163214286.0     174.0
# 3518              G    7000000.0    1889522.0      99.0
# 3563              G    6500000.0          NaN     115.0
# 3708              G    5000000.0          NaN     113.0
# 3723              G    5000000.0   19421271.0      77.0
# 3970              G    3977000.0  198655278.0     226.0
# 4024              G    8000000.0   77413017.0      80.0
# 4062              G    3000000.0          NaN      95.0
# 4064              G   16000000.0          NaN      93.0
# 4093              G    3000000.0          NaN      89.0
# 4162              G    2700000.0          NaN     118.0
# 4185              G    2500000.0          NaN      98.0
# 4225              G    2280000.0   76400000.0     120.0
# 4362              G    1800000.0          NaN      96.0
# 4427              G    1500000.0     163245.0      87.0
# 4591              G    1000000.0     100240.0      93.0
# 4725              G     500000.0   39552600.0      86.0
# 4787              G     450000.0          NaN      52.0
# 4874              G          NaN          NaN      93.0
#
#                                                  genres          actor_1_name  \
# 35            Adventure|Animation|Comedy|Family|Fantasy         Steve Buscemi
# 41              Adventure|Animation|Comedy|Family|Sport          Joe Mantegna
# 43            Adventure|Animation|Comedy|Family|Fantasy             Tom Hanks
# 58                    Adventure|Animation|Family|Sci-Fi     John Ratzenberger
# 91                   Adventure|Animation|Family|Fantasy             Tom Hanks
# 119                     Animation|Comedy|Family|Fantasy      Janeane Garofalo
# 209           Adventure|Animation|Comedy|Family|Musical         Miguel Ferrer
# 238           Adventure|Animation|Comedy|Family|Fantasy         Steve Buscemi
# 277            Animation|Family|Fantasy|Musical|Romance         Oprah Winfrey
# 297              Animation|Drama|Family|Musical|Romance            Demi Moore
# 298           Adventure|Animation|Comedy|Family|Fantasy           Eartha Kitt
# 323                   Adventure|Animation|Comedy|Family     Francesca Capaldi
# 338                   Adventure|Animation|Comedy|Family       Alexander Gould
# 353           Adventure|Animation|Comedy|Family|Fantasy             Tom Hanks
# 362      Adventure|Animation|Family|Fantasy|Musical|War           Ming-Na Wen
# 384           Adventure|Animation|Comedy|Family|Musical         Anne Hathaway
# 406                             Adventure|Comedy|Family         Ioan Gruffudd
# 444                               Comedy|Family|Fantasy         Steve Buscemi
# 448     Adventure|Animation|Comedy|Family|Fantasy|Music           Amy Poehler
# 473                  Adventure|Animation|Family|Western            Matt Damon
# 480                      Animation|Family|Fantasy|Music          Quincy Jones
# 500               Adventure|Comedy|Drama|Family|Fantasy         Adam Goldberg
# 504                                   Documentary|Drama  Pedro Armendáriz Jr.
# 509            Adventure|Animation|Drama|Family|Musical     Matthew Broderick
# 583             Adventure|Animation|Comedy|Family|Sport     John Ratzenberger
# 657                               Comedy|Family|Fantasy        Judge Reinhold
# 714            Adventure|Animation|Comedy|Family|Sci-Fi      Catherine O'Hara
# 756           Adventure|Animation|Comedy|Family|Fantasy           Emma Watson
# 839   Adventure|Animation|Drama|Family|History|Music...        Christian Bale
# 902   Adventure|Animation|Drama|Family|Fantasy|Music...         Kirsten Dunst
# ...                                                 ...                   ...
# 2913                         Adventure|Animation|Family          Judith Barsi
# 2943                Comedy|Drama|Family|Fantasy|Musical     Steven Mackintosh
# 3028          Comedy|Drama|Family|Music|Musical|Romance         Lucas Grabeel
# 3079                           Adventure|Mystery|Sci-Fi           Keir Dullea
# 3101                           Action|Drama|History|War        Richard Burton
# 3107                               Drama|Family|Musical           Oliver Reed
# 3109             Animation|Comedy|Family|Mystery|Sci-Fi        Diedrich Bader
# 3142                                       Drama|Family          Julia Ormond
# 3179                                    Biography|Drama          Sissy Spacek
# 3280                       Drama|Family|Musical|Romance                 Topol
# 3356                    Adventure|Comedy|Family|Musical         Madeline Kahn
# 3359             Biography|Drama|Family|Musical|Romance        Eleanor Parker
# 3518                                        Drama|Sport         Ellen Burstyn
# 3563                                    Sci-Fi|Thriller           David Wayne
# 3708                               Comedy|Crime|Mystery            Burt Kwouk
# 3723                            Animation|Comedy|Family          Frank Welker
# 3970                          Drama|History|Romance|War       Hattie McDaniel
# 4024                                        Documentary        Morgan Freeman
# 4062                            Action|Adventure|Sci-Fi        Linda Harrison
# 4064   Action|Adventure|Animation|Family|Fantasy|Sci-Fi       Veronica Taylor
# 4093                             Family|Fantasy|Musical          Peter Ostrum
# 4162                             Adventure|Family|Sport             Teri Garr
# 4185                                      Action|Sci-Fi        Roddy McDowall
# 4225                     Animation|Family|Fantasy|Music     Leopold Stokowski
# 4362                                      Action|Sci-Fi        Roddy McDowall
# 4427                                Comedy|Drama|Family      Paulette Goddard
# 4591                                        Documentary           G.W. Krauss
# 4725                           Adventure|Family|Romance        Frances Bavier
# 4787                                        Documentary           Bob Proctor
# 4874                                      Drama|Musical     Dustin Fitzsimons
#
#              actor_2_name       actor_3_name      director_name  language  \
# 35           Tyler Labine         Sean Hayes        Dan Scanlon   English
# 41     Thomas Kretschmann       Eddie Izzard      John Lasseter   English
# 43      John Ratzenberger        Don Rickles        Lee Unkrich   English
# 58           Fred Willard        Jeff Garlin     Andrew Stanton   English
# 91           Eddie Deezen      Peter Scolari    Robert Zemeckis   English
# 119     John Ratzenberger      Brian Dennehy          Brad Bird   English
# 209           Rachel Crow     Jeffrey Garcia    Carlos Saldanha   English
# 238     John Ratzenberger       James Coburn        Pete Docter   English
# 277         Jenifer Lewis    Anika Noni Rose       Ron Clements   English
# 297       Jason Alexander    Bill Fagerbakke     Gary Trousdale   English
# 298         Wendie Malick       John Fiedler        Mark Dindal   English
# 323      Venus Schultheis      Bill Melendez      Steve Martino   English
# 338          Stephen Root       Brad Garrett     Andrew Stanton   English
# 353     John Ratzenberger       Wayne Knight      John Lasseter   English
# 362      Harvey Fierstein         June Foray      Tony Bancroft   English
# 384           Wanda Sykes          Will.i.am    Carlos Saldanha   English
# 406             Eric Idle         Jim Carter         Kevin Lima   English
# 444         Julia Roberts      Oprah Winfrey        Gary Winick   English
# 448       Jesse McCartney    Lauren Gottlieb      Mike Mitchell   English
# 473        Charles Napier     Zahn McClarnon       Kelly Asbury   English
# 480         Penn Jillette       Russi Taylor        James Algar   English
# 500       Elizabeth Daily      Glenne Headly      George Miller   English
# 504        Jacques Perrin       Rie Miyazawa     Jacques Perrin    French
# 509           Nathan Lane      Niketa Calame       Roger Allers   English
# 583          Cheech Marin      George Carlin      John Lasseter   English
# 657           Aisha Tyler         Eric Lloyd    Michael Lembeck   English
# 714          Fred Willard        Amy Sedaris        Mark Dindal   English
# 756     Matthew Broderick     Frank Langella           Sam Fell   English
# 839          Frank Welker       Irene Bedard       Mike Gabriel   English
# 902        Kelsey Grammer  Bernadette Peters          Don Bluth   English
# ...                   ...                ...                ...       ...
# 2913        Gabriel Damon         Bill Erwin          Don Bluth   English
# 2943         Jerry Nelson     Steve Whitmire       Brian Henson   English
# 3028          Matt Prokop        Corbin Bleu       Kenny Ortega   English
# 3079        Gary Lockwood         Glenn Beck    Stanley Kubrick   English
# 3101       Richard Beymer       Eddie Albert        Ken Annakin   English
# 3107            Ron Moody          Jack Wild         Carol Reed   English
# 3109      Andrew Lawrence     Dabney Coleman       Chuck Sheetz   English
# 3142       Jane Krakowski       Willow Smith    Patricia Rozema   English
# 3179   Richard Farnsworth     Everett McGill        David Lynch   English
# 3280  Paul Michael Glaser    Rosalind Harris     Norman Jewison   English
# 3356           Jim Henson        Dom DeLuise      James Frawley   English
# 3359    Angela Cartwright   Nicholas Hammond        Robert Wise   English
# 3518       Marley Shelton    Jennifer Butler       Tim Chambers   English
# 3563          Paula Kelly     Eric Christmas        Robert Wise   English
# 3708          Herbert Lom   Catherine Schell      Blake Edwards   English
# 3723    Constance Shulman      Alice Playten      Maurice Joyce   English
# 3970        George Reeves    Thomas Mitchell     Victor Fleming   English
# 4024         Sofie Gråbøl   Romane Bohringer        Luc Jacquet    French
# 4062       Gregory Sierra       Victor Buono           Ted Post   English
# 4064          Eric Stuart         Lisa Ortiz    Kunihiko Yuyama  Japanese
# 4093       Jack Albertson    Julie Dawn Cole         Mel Stuart   English
# 4162           Kelly Reno         Hoyt Axton    Carroll Ballard   English
# 4185       M. Emmet Walsh          Sal Mineo         Don Taylor   English
# 4225         Deems Taylor                NaN        James Algar   English
# 4362        Paul Williams       Claude Akins    J. Lee Thompson   English
# 4427     Stanley Blystone     Fred Malatesta    Charles Chaplin   English
# 4591       Brian Whitaker      Jason Bateman      Kief Davidson   English
# 4725          Peter Breck     Edgar Buchanan           Joe Camp   English
# 4787        Jack Canfield         Eric Worre       Joe Kenemore   English
# 4874          Mark Hengst    Debra Lynn Hull  Rachel Goldenberg   English
#
#         country  aspect_ratio  title_year
# 35          USA          1.85      2013.0
# 41          USA          2.35      2011.0
# 43          USA          1.85      2010.0
# 58          USA          2.35      2008.0
# 91          USA          2.35      2004.0
# 119         USA          2.35      2007.0
# 209         USA          2.35      2014.0
# 238         USA          1.85      2001.0
# 277         USA          1.85      2009.0
# 297         USA          1.78      1996.0
# 298         USA          1.66      2000.0
# 323         USA          1.85      2015.0
# 338         USA          1.85      2003.0
# 353         USA          1.85      1999.0
# 362         USA          1.66      1998.0
# 384         USA          2.35      2011.0
# 406         USA          1.85      2000.0
# 444         USA          1.85      2006.0
# 448         USA          1.85      2011.0
# 473         USA          2.35      2002.0
# 480         USA          1.78      1999.0
# 500   Australia          1.85      1998.0
# 504      France          2.35      2009.0
# 509         USA          1.66      1994.0
# 583         USA          2.35      2006.0
# 657         USA          1.85      2002.0
# 714         USA          1.85      2005.0
# 756          UK          2.35      2008.0
# 839         USA          1.78      1995.0
# 902         USA          2.35      1997.0
# ...         ...           ...         ...
# 2913        USA          1.33      1988.0
# 2943        USA          1.85      1992.0
# 3028        USA          1.85      2008.0
# 3079         UK          2.20      1968.0
# 3101        USA          2.35      1962.0
# 3107         UK          2.35      1968.0
# 3109        USA          1.85      2001.0
# 3142        USA          1.85      2008.0
# 3179     France          2.35      1999.0
# 3280        USA          2.35      1971.0
# 3356         UK          1.85      1979.0
# 3359        USA          2.35      1965.0
# 3518        USA          2.35      2009.0
# 3563        USA          2.35      1971.0
# 3708         UK          2.35      1975.0
# 3723        USA          1.33      1999.0
# 3970        USA          1.37      1939.0
# 4024     France          1.85      2005.0
# 4062        USA          2.35      1970.0
# 4064      Japan          1.85      2000.0
# 4093        USA          1.33      1971.0
# 4162        USA          1.85      1979.0
# 4185        USA          2.35      1971.0
# 4225        USA          1.37      1940.0
# 4362        USA          2.35      1973.0
# 4427        USA          1.37      1936.0
# 4591    Denmark           NaN      2014.0
# 4725        USA          1.85      1974.0
# 4787        USA           NaN      2014.0
# 4874        USA          1.85      2008.0
#
# [112 rows x 15 columns]

# %% [markdown]
# What if we wanted to find movies that were either `G`, `PG`, or `PG-13`?
# We'd have to type out something pretty annoying like:
# ```python
# movies[(movies.content_rating == 'G') | (movies.content_rating == 'PG') | (movies.content_rating == 'PG-13')]
# ```
#
# <br>Instead, we'll use the `.isin()` operator to match against a group. Remember, `.isin()` accepts a `list` only

# %%
movies[movies.content_rating.isin(['G','PG', 'PG-13'])]
# Out:
#                                        movie_title  imdb_score content_rating  \
# 0                                          Avatar          7.9          PG-13
# 1        Pirates of the Caribbean: At World's End          7.1          PG-13
# 2                                         Spectre          6.8          PG-13
# 3                           The Dark Knight Rises          8.5          PG-13
# 5                                     John Carter          6.6          PG-13
# 6                                    Spider-Man 3          6.2          PG-13
# 7                                         Tangled          7.8             PG
# 8                         Avengers: Age of Ultron          7.5          PG-13
# 9          Harry Potter and the Half-Blood Prince          7.5             PG
# 10             Batman v Superman: Dawn of Justice          6.9          PG-13
# 11                               Superman Returns          6.1          PG-13
# 12                              Quantum of Solace          6.7          PG-13
# 13     Pirates of the Caribbean: Dead Man's Chest          7.3          PG-13
# 14                                The Lone Ranger          6.5          PG-13
# 15                                   Man of Steel          7.2          PG-13
# 16       The Chronicles of Narnia: Prince Caspian          6.6             PG
# 17                                   The Avengers          8.1          PG-13
# 18    Pirates of the Caribbean: On Stranger Tides          6.7          PG-13
# 19                                 Men in Black 3          6.8          PG-13
# 20      The Hobbit: The Battle of the Five Armies          7.5          PG-13
# 21                         The Amazing Spider-Man          7.0          PG-13
# 22                                     Robin Hood          6.7          PG-13
# 23            The Hobbit: The Desolation of Smaug          7.9          PG-13
# 24                             The Golden Compass          6.1          PG-13
# 25                                      King Kong          7.2          PG-13
# 26                                        Titanic          7.7          PG-13
# 27                     Captain America: Civil War          8.2          PG-13
# 28                                     Battleship          5.9          PG-13
# 29                                 Jurassic World          7.0          PG-13
# 30                                        Skyfall          7.8          PG-13
# ...                                            ...         ...            ...
# 4842                          Across the Universe          7.4          PG-13
# 4864                                   Like Crazy          6.7          PG-13
# 4871                              Shotgun Stories          7.3          PG-13
# 4874                        Sunday School Musical          2.5              G
# 4875                                         Rust          5.7             PG
# 4877                          The Christmas Bunny          6.2             PG
# 4880                                    UnDivided          7.8             PG
# 4881                                   The Frozen          4.4          PG-13
# 4883                                   Horse Camp          6.6             PG
# 4900                               The Grace Card          6.4          PG-13
# 4904                              Call + Response          7.5          PG-13
# 4908                                 Super Hybrid          3.9          PG-13
# 4915                    The Trials of Darryl Hunt          7.7          PG-13
# 4917                          Yesterday Was a Lie          5.4             PG
# 4921                           Children of Heaven          8.5             PG
# 4926                                Another Earth          7.0          PG-13
# 4930                                      Tadpole          6.3          PG-13
# 4935                               Heroes of Dirt          7.1          PG-13
# 4948                             Romantic Schemer          5.1          PG-13
# 4955                            Facing the Giants          6.7             PG
# 4960                                   The Mighty          7.3          PG-13
# 4962                 The Lost Skeleton of Cadavra          7.0             PG
# 4963                       Dude, Where's My Dog?!          3.2             PG
# 4977                                Super Size Me          7.3             PG
# 4993                                   The Signal          6.1          PG-13
# 5001                               The Last Waltz          8.2             PG
# 5033                                       Primer          7.0          PG-13
# 5036                              The Mongol King          7.8          PG-13
# 5041                             Shanghai Calling          6.3          PG-13
# 5042                            My Date with Drew          6.6             PG
#
#            budget        gross  duration  \
# 0     237000000.0  760505847.0     178.0
# 1     300000000.0  309404152.0     169.0
# 2     245000000.0  200074175.0     148.0
# 3     250000000.0  448130642.0     164.0
# 5     263700000.0   73058679.0     132.0
# 6     258000000.0  336530303.0     156.0
# 7     260000000.0  200807262.0     100.0
# 8     250000000.0  458991599.0     141.0
# 9     250000000.0  301956980.0     153.0
# 10    250000000.0  330249062.0     183.0
# 11    209000000.0  200069408.0     169.0
# 12    200000000.0  168368427.0     106.0
# 13    225000000.0  423032628.0     151.0
# 14    215000000.0   89289910.0     150.0
# 15    225000000.0  291021565.0     143.0
# 16    225000000.0  141614023.0     150.0
# 17    220000000.0  623279547.0     173.0
# 18    250000000.0  241063875.0     136.0
# 19    225000000.0  179020854.0     106.0
# 20    250000000.0  255108370.0     164.0
# 21    230000000.0  262030663.0     153.0
# 22    200000000.0  105219735.0     156.0
# 23    225000000.0  258355354.0     186.0
# 24    180000000.0   70083519.0     113.0
# 25    207000000.0  218051260.0     201.0
# 26    200000000.0  658672302.0     194.0
# 27    250000000.0  407197282.0     147.0
# 28    209000000.0   65173160.0     131.0
# 29    150000000.0  652177271.0     124.0
# 30    200000000.0  304360277.0     143.0
# ...           ...          ...       ...
# 4842   45000000.0   24343673.0     133.0
# 4864     250000.0    3388210.0      90.0
# 4871          NaN      45661.0      92.0
# 4874          NaN          NaN      93.0
# 4875     250000.0          NaN      95.0
# 4877     250000.0          NaN      98.0
# 4880     250000.0          NaN      66.0
# 4881     250000.0          NaN      95.0
# 4883     250000.0          NaN     108.0
# 4900     200000.0    2428241.0     101.0
# 4904     200000.0     215185.0      86.0
# 4908   13000000.0          NaN      94.0
# 4915     200000.0       1111.0     106.0
# 4917    2500000.0          NaN      89.0
# 4921     180000.0     925402.0      89.0
# 4926     100000.0    1316074.0      92.0
# 4930     150000.0    2882062.0      78.0
# 4935          NaN          NaN      98.0
# 4948     125000.0          NaN       NaN
# 4955     100000.0   10174663.0     111.0
# 4960          NaN    2643689.0     100.0
# 4962      40000.0     110536.0      90.0
# 4963      20000.0          NaN      82.0
# 4977      65000.0   11529368.0     100.0
# 4993    4000000.0          NaN      97.0
# 5001          NaN     321952.0     117.0
# 5033       7000.0     424760.0      77.0
# 5036       3250.0          NaN      84.0
# 5041          NaN      10443.0     100.0
# 5042       1100.0      85222.0      90.0
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 1                              Action|Adventure|Fantasy          Johnny Depp
# 2                             Action|Adventure|Thriller      Christoph Waltz
# 3                                       Action|Thriller            Tom Hardy
# 5                               Action|Adventure|Sci-Fi         Daryl Sabara
# 6                              Action|Adventure|Romance         J.K. Simmons
# 7     Adventure|Animation|Comedy|Family|Fantasy|Musi...         Brad Garrett
# 8                               Action|Adventure|Sci-Fi      Chris Hemsworth
# 9                      Adventure|Family|Fantasy|Mystery         Alan Rickman
# 10                              Action|Adventure|Sci-Fi         Henry Cavill
# 11                              Action|Adventure|Sci-Fi         Kevin Spacey
# 12                                     Action|Adventure   Giancarlo Giannini
# 13                             Action|Adventure|Fantasy          Johnny Depp
# 14                             Action|Adventure|Western          Johnny Depp
# 15                      Action|Adventure|Fantasy|Sci-Fi         Henry Cavill
# 16                      Action|Adventure|Family|Fantasy       Peter Dinklage
# 17                              Action|Adventure|Sci-Fi      Chris Hemsworth
# 18                             Action|Adventure|Fantasy          Johnny Depp
# 19        Action|Adventure|Comedy|Family|Fantasy|Sci-Fi           Will Smith
# 20                                    Adventure|Fantasy         Aidan Turner
# 21                             Action|Adventure|Fantasy           Emma Stone
# 22                       Action|Adventure|Drama|History            Mark Addy
# 23                                    Adventure|Fantasy         Aidan Turner
# 24                             Adventure|Family|Fantasy      Christopher Lee
# 25                       Action|Adventure|Drama|Romance          Naomi Watts
# 26                                        Drama|Romance    Leonardo DiCaprio
# 27                              Action|Adventure|Sci-Fi    Robert Downey Jr.
# 28                     Action|Adventure|Sci-Fi|Thriller          Liam Neeson
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 30                            Action|Adventure|Thriller        Albert Finney
# ...                                                 ...                  ...
# 4842                      Drama|Fantasy|Musical|Romance         Jim Sturgess
# 4864                                      Drama|Romance    Jennifer Lawrence
# 4871                                     Drama|Thriller   Michael Abbott Jr.
# 4874                                      Drama|Musical    Dustin Fitzsimons
# 4875                                              Drama       Corbin Bernsen
# 4877                                       Drama|Family   Florence Henderson
# 4880                                        Documentary            Sam Adams
# 4881                                    Horror|Thriller           Noah Segan
# 4883                                             Family      Joshua Ray Bell
# 4900                                              Drama       Michael Joiner
# 4904                          Documentary|History|Music            Matisyahu
# 4908                             Horror|Sci-Fi|Thriller      Melanie Papalia
# 4915                                  Crime|Documentary          Darryl Hunt
# 4917                 Drama|Music|Mystery|Romance|Sci-Fi          John Newton
# 4921                                       Drama|Family       Bahare Seddiqi
# 4926                               Drama|Romance|Sci-Fi    Robin Lord Taylor
# 4930                               Comedy|Drama|Romance        Bebe Neuwirth
# 4935                                 Action|Drama|Sport           Joel Moody
# 4948                                            Romance     Diane Sorrentino
# 4955                                        Drama|Sport        Alex Kendrick
# 4960                                       Comedy|Drama        Kieran Culkin
# 4962                               Comedy|Horror|Sci-Fi        Fay Masterson
# 4963                                             Family      Kevin P. Farley
# 4977                           Comedy|Documentary|Drama      Chemeeka Walker
# 4993                                    Sci-Fi|Thriller            Lin Shaye
# 5001                                  Documentary|Music          Ringo Starr
# 5033                              Drama|Sci-Fi|Thriller        Shane Carruth
# 5036                                        Crime|Drama       Richard Jewell
# 5041                               Comedy|Drama|Romance            Alan Ruck
# 5042                                        Documentary          John August
#
#                 actor_2_name          actor_3_name      director_name  \
# 0           Joel David Moore             Wes Studi      James Cameron
# 1              Orlando Bloom        Jack Davenport     Gore Verbinski
# 2               Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3             Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 5            Samantha Morton          Polly Walker     Andrew Stanton
# 6               James Franco         Kirsten Dunst          Sam Raimi
# 7               Donna Murphy           M.C. Gainey       Nathan Greno
# 8          Robert Downey Jr.    Scarlett Johansson        Joss Whedon
# 9           Daniel Radcliffe          Rupert Grint        David Yates
# 10              Lauren Cohan        Alan D. Purwin        Zack Snyder
# 11             Marlon Brando        Frank Langella       Bryan Singer
# 12           Mathieu Amalric          Rory Kinnear       Marc Forster
# 13             Orlando Bloom        Jack Davenport     Gore Verbinski
# 14               Ruth Wilson         Tom Wilkinson     Gore Verbinski
# 15        Christopher Meloni          Harry Lennix        Zack Snyder
# 16      Pierfrancesco Favino        Damián Alcázar     Andrew Adamson
# 17         Robert Downey Jr.    Scarlett Johansson        Joss Whedon
# 18               Sam Claflin        Stephen Graham       Rob Marshall
# 19         Michael Stuhlbarg    Nicole Scherzinger   Barry Sonnenfeld
# 20                Adam Brown         James Nesbitt      Peter Jackson
# 21           Andrew Garfield           Chris Zylka          Marc Webb
# 22              William Hurt          Scott Grimes       Ridley Scott
# 23                Adam Brown         James Nesbitt      Peter Jackson
# 24                 Eva Green  Kristin Scott Thomas        Chris Weitz
# 25        Thomas Kretschmann            Evan Parke      Peter Jackson
# 26              Kate Winslet         Gloria Stuart      James Cameron
# 27        Scarlett Johansson           Chris Evans      Anthony Russo
# 28       Alexander Skarsgård        Tadanobu Asano         Peter Berg
# 29                Judy Greer               Omar Sy    Colin Trevorrow
# 30             Helen McCrory          Rory Kinnear         Sam Mendes
# ...                      ...                   ...                ...
# 4842             T.V. Carpio       Robert Clohessy       Julie Taymor
# 4864          Charlie Bewley         Finola Hughes      Drake Doremus
# 4871        Natalie Canerday          Travis Smith       Jeff Nichols
# 4874             Mark Hengst       Debra Lynn Hull  Rachel Goldenberg
# 4875          Lorne Cardinal       Kirsten Collins     Corbin Bernsen
# 4877           Derek Brandon  Charles Irving Beale        Tom Seidman
# 4880              Steve Duin            Jeff Jacob         Sam Martin
# 4881             Brit Morgan          Sedona James       Andrew Hyatt
# 4883         Dana Blackstone        Annelyse Ahmad   Joel Paul Reisig
# 4900            Chris Thomas  Michael Higgenbottom     David G. Evans
# 4904     Natasha Bedingfield    Madeleine Albright      Justin Dillon
# 4908            Ryan Kennedy          John Reardon       Eric Valette
# 4915        Evelyn Jefferson           John Reeves        Ricki Stern
# 4917         Chase Masterson           H.M. Wynant       James Kerwin
# 4921  Amir Farrokh Hashemian    Mohammad Amir Naji       Majid Majidi
# 4926        William Mapother        Flint Beverage        Mike Cahill
# 4930          Aaron Stanford            Ron Rifkin        Gary Winick
# 4935              Bill Allen            Lia Tucker        Eric Bugbee
# 4948               Valentine                   NaN          Valentine
# 4955             Erin Bethea        Shannen Fields      Alex Kendrick
# 4960            Elden Henson         Gena Rowlands      Peter Chelsom
# 4962              Brian Howe         Larry Blamire      Larry Blamire
# 4963       Gabriela Castillo     Brandon Middleton   Stephen Langford
# 4977          Amanda Kearsan      Amelia Giancarlo    Morgan Spurlock
# 4993            Olivia Cooke            Beau Knapp     William Eubank
# 5001              Levon Helm             Bob Dylan    Martin Scorsese
# 5033          David Sullivan          Casey Gooden      Shane Carruth
# 5036          John Considine        Sara Stepnicka    Anthony Vallone
# 5041           Daniel Henney           Eliza Coupe        Daniel Hsia
# 5042        Brian Herzlinger              Jon Gunn           Jon Gunn
#
#      language      country  aspect_ratio  title_year
# 0     English          USA          1.78      2009.0
# 1     English          USA          2.35      2007.0
# 2     English           UK          2.35      2015.0
# 3     English          USA          2.35      2012.0
# 5     English          USA          2.35      2012.0
# 6     English          USA          2.35      2007.0
# 7     English          USA          1.85      2010.0
# 8     English          USA          2.35      2015.0
# 9     English           UK          2.35      2009.0
# 10    English          USA          2.35      2016.0
# 11    English          USA          2.35      2006.0
# 12    English           UK          2.35      2008.0
# 13    English          USA          2.35      2006.0
# 14    English          USA          2.35      2013.0
# 15    English          USA          2.35      2013.0
# 16    English          USA          2.35      2008.0
# 17    English          USA          1.85      2012.0
# 18    English          USA          2.35      2011.0
# 19    English          USA          1.85      2012.0
# 20    English  New Zealand          2.35      2014.0
# 21    English          USA          2.35      2012.0
# 22    English          USA          2.35      2010.0
# 23    English          USA          2.35      2013.0
# 24    English          USA          2.35      2007.0
# 25    English  New Zealand          2.35      2005.0
# 26    English          USA          2.35      1997.0
# 27    English          USA          2.35      2016.0
# 28    English          USA          2.35      2012.0
# 29    English          USA          2.00      2015.0
# 30    English           UK          2.35      2012.0
# ...       ...          ...           ...         ...
# 4842  English          USA          2.35      2007.0
# 4864  English          USA          1.78      2011.0
# 4871  English          USA          2.35      2007.0
# 4874  English          USA          1.85      2008.0
# 4875  English       Canada          1.78      2010.0
# 4877  English          USA           NaN      2010.0
# 4880  English          USA           NaN      2013.0
# 4881  English          USA           NaN      2012.0
# 4883  English          USA           NaN      2014.0
# 4900  English          USA           NaN      2010.0
# 4904  English          USA           NaN      2008.0
# 4908  English          USA          2.35      2010.0
# 4915  English          USA          1.66      2006.0
# 4917  English          USA          1.78      2008.0
# 4921  Persian         Iran          1.85      1997.0
# 4926  English          USA          1.85      2011.0
# 4930  English          USA          1.85      2000.0
# 4935  English          USA           NaN      2015.0
# 4948  English          USA           NaN      2015.0
# 4955  English          USA          1.85      2006.0
# 4960  English          USA          1.85      1998.0
# 4962  English          USA          1.85      2001.0
# 4963  English          USA          1.85      2014.0
# 4977  English          USA          1.78      2004.0
# 4993  English          USA          2.35      2014.0
# 5001  English          USA          1.85      1978.0
# 5033  English          USA          1.85      2004.0
# 5036  English          USA           NaN      2005.0
# 5041  English          USA          2.35      2012.0
# 5042  English          USA          1.85      2004.0
#
# [2274 rows x 15 columns]

# %% [markdown]
# ### Masking

# %% [markdown]
# What's going on under the hood? When we say something like this,
# ```python
# movies.content_rating == 'G'
# ```
# We're actually asking Pandas to check that **for each** row in the series, if the given statement is True or False.

# %%
movies.content_rating == 'G'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 5013    False
# 5014    False
# 5015    False
# 5016    False
# 5017    False
# 5018    False
# 5019    False
# 5020    False
# 5021    False
# 5022    False
# 5023    False
# 5024    False
# 5025    False
# 5026    False
# 5027    False
# 5028    False
# 5029    False
# 5030    False
# 5031    False
# 5032    False
# 5033    False
# 5034    False
# 5035    False
# 5036    False
# 5037    False
# 5038    False
# 5039    False
# 5040    False
# 5041    False
# 5042    False
# Name: content_rating, Length: 5043, dtype: bool

# %%
movies[  movies.content_rating == 'G'  ]
# Out:
#                                             movie_title  imdb_score  \
# 35                                 Monsters University          7.3
# 41                                              Cars 2          6.3
# 43                                         Toy Story 3          8.3
# 58                                              WALL·E          8.4
# 91                                   The Polar Express          6.6
# 119                                        Ratatouille          8.0
# 209                                              Rio 2          6.4
# 238                                     Monsters, Inc.          8.1
# 277                          The Princess and the Frog          7.1
# 297                        The Hunchback of Notre Dame          6.9
# 298                           The Emperor's New Groove          7.3
# 323                                  The Peanuts Movie          7.2
# 338                                       Finding Nemo          8.2
# 353                                        Toy Story 2          7.9
# 362                                              Mulan          7.5
# 384                                                Rio          7.0
# 406                                     102 Dalmatians          4.8
# 444                                    Charlotte's Web          6.4
# 448               Alvin and the Chipmunks: Chipwrecked          4.4
# 473                   Spirit: Stallion of the Cimarron          7.0
# 480                                      Fantasia 2000          7.3
# 500                              Babe: Pig in the City          5.8
# 504                                             Oceans          7.8
# 509                                      The Lion King          8.5
# 583                                               Cars          7.2
# 657                                 The Santa Clause 2          5.5
# 714                                     Chicken Little          5.8
# 756                             The Tale of Despereaux          6.1
# 839                                         Pocahontas          6.6
# 902                                          Anastasia          7.1
# ...                                                 ...         ...
# 2913                              The Land Before Time          7.3
# 2943                        The Muppet Christmas Carol          7.7
# 3028                High School Musical 3: Senior Year          4.5
# 3079                             2001: A Space Odyssey          8.3
# 3101                                   The Longest Day          7.8
# 3107                                           Oliver!          7.5
# 3109                              Recess: School's Out          6.5
# 3142                   Kit Kittredge: An American Girl          6.7
# 3179                                The Straight Story          8.0
# 3280                               Fiddler on the Roof          8.0
# 3356                                  The Muppet Movie          7.7
# 3359                                The Sound of Music          8.0
# 3518                                   The Mighty Macs          6.5
# 3563                              The Andromeda Strain          7.2
# 3708                    The Return of the Pink Panther          7.1
# 3723                                  Doug's 1st Movie          5.0
# 3970                                Gone with the Wind          8.2
# 4024                             March of the Penguins          7.6
# 4062                    Beneath the Planet of the Apes          6.1
# 4064                              Pokémon 3: The Movie          5.6
# 4093               Willy Wonka & the Chocolate Factory          7.8
# 4162                                The Black Stallion          7.4
# 4185                Escape from the Planet of the Apes          6.3
# 4225                                          Fantasia          7.8
# 4362                 Battle for the Planet of the Apes          5.5
# 4427                                      Modern Times          8.6
# 4591                              A Lego Brickumentary          6.8
# 4725                                             Benji          6.1
# 4787  Rise of the Entrepreneur: The Search for a Bet...         8.2
# 4874                             Sunday School Musical          2.5
#
#      content_rating       budget        gross  duration  \
# 35                G  200000000.0  268488329.0     104.0
# 41                G  200000000.0  191450875.0     106.0
# 43                G  200000000.0  414984497.0     103.0
# 58                G  180000000.0  223806889.0      98.0
# 91                G  165000000.0     665426.0     100.0
# 119               G  150000000.0  206435493.0     111.0
# 209               G  103000000.0  131536019.0     101.0
# 238               G  115000000.0  289907418.0      92.0
# 277               G  105000000.0  104374107.0      97.0
# 297               G  100000000.0  100117603.0      91.0
# 298               G  100000000.0   89296573.0      78.0
# 323               G   99000000.0  130174897.0      88.0
# 338               G   94000000.0  380838870.0     100.0
# 353               G   90000000.0  245823397.0      82.0
# 362               G   90000000.0  120618403.0      88.0
# 384               G   90000000.0  143618384.0      96.0
# 406               G   85000000.0   66941559.0     100.0
# 444               G          NaN   82506325.0      97.0
# 448               G   75000000.0  133103929.0      87.0
# 473               G   80000000.0   73215310.0      83.0
# 480               G   80000000.0   60507228.0      74.0
# 500               G   80000000.0   18318000.0      97.0
# 504               G   40000000.0   19406406.0     104.0
# 509               G   45000000.0  422783777.0      73.0
# 583               G  120000000.0  244052771.0     117.0
# 657               G   60000000.0  139225854.0     104.0
# 714               G  150000000.0  135381507.0      81.0
# 756               G   60000000.0   50818750.0      93.0
# 839               G   55000000.0  141600000.0      84.0
# 902               G   50000000.0   58297830.0      94.0
# ...             ...          ...          ...       ...
# 2913              G   12500000.0   48092846.0      69.0
# 2943              G   12000000.0   27281507.0      89.0
# 3028              G   11000000.0   90556401.0     112.0
# 3079              G   12000000.0   56715371.0     161.0
# 3101              G   10000000.0          NaN     178.0
# 3107              G   10000000.0   16800000.0     153.0
# 3109              G   23000000.0   36696761.0      82.0
# 3142              G   10000000.0   17655201.0     101.0
# 3179              G   10000000.0    6197866.0     112.0
# 3280              G    9000000.0   50000000.0     181.0
# 3356              G          NaN   76657000.0      95.0
# 3359              G    8200000.0  163214286.0     174.0
# 3518              G    7000000.0    1889522.0      99.0
# 3563              G    6500000.0          NaN     115.0
# 3708              G    5000000.0          NaN     113.0
# 3723              G    5000000.0   19421271.0      77.0
# 3970              G    3977000.0  198655278.0     226.0
# 4024              G    8000000.0   77413017.0      80.0
# 4062              G    3000000.0          NaN      95.0
# 4064              G   16000000.0          NaN      93.0
# 4093              G    3000000.0          NaN      89.0
# 4162              G    2700000.0          NaN     118.0
# 4185              G    2500000.0          NaN      98.0
# 4225              G    2280000.0   76400000.0     120.0
# 4362              G    1800000.0          NaN      96.0
# 4427              G    1500000.0     163245.0      87.0
# 4591              G    1000000.0     100240.0      93.0
# 4725              G     500000.0   39552600.0      86.0
# 4787              G     450000.0          NaN      52.0
# 4874              G          NaN          NaN      93.0
#
#                                                  genres          actor_1_name  \
# 35            Adventure|Animation|Comedy|Family|Fantasy         Steve Buscemi
# 41              Adventure|Animation|Comedy|Family|Sport          Joe Mantegna
# 43            Adventure|Animation|Comedy|Family|Fantasy             Tom Hanks
# 58                    Adventure|Animation|Family|Sci-Fi     John Ratzenberger
# 91                   Adventure|Animation|Family|Fantasy             Tom Hanks
# 119                     Animation|Comedy|Family|Fantasy      Janeane Garofalo
# 209           Adventure|Animation|Comedy|Family|Musical         Miguel Ferrer
# 238           Adventure|Animation|Comedy|Family|Fantasy         Steve Buscemi
# 277            Animation|Family|Fantasy|Musical|Romance         Oprah Winfrey
# 297              Animation|Drama|Family|Musical|Romance            Demi Moore
# 298           Adventure|Animation|Comedy|Family|Fantasy           Eartha Kitt
# 323                   Adventure|Animation|Comedy|Family     Francesca Capaldi
# 338                   Adventure|Animation|Comedy|Family       Alexander Gould
# 353           Adventure|Animation|Comedy|Family|Fantasy             Tom Hanks
# 362      Adventure|Animation|Family|Fantasy|Musical|War           Ming-Na Wen
# 384           Adventure|Animation|Comedy|Family|Musical         Anne Hathaway
# 406                             Adventure|Comedy|Family         Ioan Gruffudd
# 444                               Comedy|Family|Fantasy         Steve Buscemi
# 448     Adventure|Animation|Comedy|Family|Fantasy|Music           Amy Poehler
# 473                  Adventure|Animation|Family|Western            Matt Damon
# 480                      Animation|Family|Fantasy|Music          Quincy Jones
# 500               Adventure|Comedy|Drama|Family|Fantasy         Adam Goldberg
# 504                                   Documentary|Drama  Pedro Armendáriz Jr.
# 509            Adventure|Animation|Drama|Family|Musical     Matthew Broderick
# 583             Adventure|Animation|Comedy|Family|Sport     John Ratzenberger
# 657                               Comedy|Family|Fantasy        Judge Reinhold
# 714            Adventure|Animation|Comedy|Family|Sci-Fi      Catherine O'Hara
# 756           Adventure|Animation|Comedy|Family|Fantasy           Emma Watson
# 839   Adventure|Animation|Drama|Family|History|Music...        Christian Bale
# 902   Adventure|Animation|Drama|Family|Fantasy|Music...         Kirsten Dunst
# ...                                                 ...                   ...
# 2913                         Adventure|Animation|Family          Judith Barsi
# 2943                Comedy|Drama|Family|Fantasy|Musical     Steven Mackintosh
# 3028          Comedy|Drama|Family|Music|Musical|Romance         Lucas Grabeel
# 3079                           Adventure|Mystery|Sci-Fi           Keir Dullea
# 3101                           Action|Drama|History|War        Richard Burton
# 3107                               Drama|Family|Musical           Oliver Reed
# 3109             Animation|Comedy|Family|Mystery|Sci-Fi        Diedrich Bader
# 3142                                       Drama|Family          Julia Ormond
# 3179                                    Biography|Drama          Sissy Spacek
# 3280                       Drama|Family|Musical|Romance                 Topol
# 3356                    Adventure|Comedy|Family|Musical         Madeline Kahn
# 3359             Biography|Drama|Family|Musical|Romance        Eleanor Parker
# 3518                                        Drama|Sport         Ellen Burstyn
# 3563                                    Sci-Fi|Thriller           David Wayne
# 3708                               Comedy|Crime|Mystery            Burt Kwouk
# 3723                            Animation|Comedy|Family          Frank Welker
# 3970                          Drama|History|Romance|War       Hattie McDaniel
# 4024                                        Documentary        Morgan Freeman
# 4062                            Action|Adventure|Sci-Fi        Linda Harrison
# 4064   Action|Adventure|Animation|Family|Fantasy|Sci-Fi       Veronica Taylor
# 4093                             Family|Fantasy|Musical          Peter Ostrum
# 4162                             Adventure|Family|Sport             Teri Garr
# 4185                                      Action|Sci-Fi        Roddy McDowall
# 4225                     Animation|Family|Fantasy|Music     Leopold Stokowski
# 4362                                      Action|Sci-Fi        Roddy McDowall
# 4427                                Comedy|Drama|Family      Paulette Goddard
# 4591                                        Documentary           G.W. Krauss
# 4725                           Adventure|Family|Romance        Frances Bavier
# 4787                                        Documentary           Bob Proctor
# 4874                                      Drama|Musical     Dustin Fitzsimons
#
#              actor_2_name       actor_3_name      director_name  language  \
# 35           Tyler Labine         Sean Hayes        Dan Scanlon   English
# 41     Thomas Kretschmann       Eddie Izzard      John Lasseter   English
# 43      John Ratzenberger        Don Rickles        Lee Unkrich   English
# 58           Fred Willard        Jeff Garlin     Andrew Stanton   English
# 91           Eddie Deezen      Peter Scolari    Robert Zemeckis   English
# 119     John Ratzenberger      Brian Dennehy          Brad Bird   English
# 209           Rachel Crow     Jeffrey Garcia    Carlos Saldanha   English
# 238     John Ratzenberger       James Coburn        Pete Docter   English
# 277         Jenifer Lewis    Anika Noni Rose       Ron Clements   English
# 297       Jason Alexander    Bill Fagerbakke     Gary Trousdale   English
# 298         Wendie Malick       John Fiedler        Mark Dindal   English
# 323      Venus Schultheis      Bill Melendez      Steve Martino   English
# 338          Stephen Root       Brad Garrett     Andrew Stanton   English
# 353     John Ratzenberger       Wayne Knight      John Lasseter   English
# 362      Harvey Fierstein         June Foray      Tony Bancroft   English
# 384           Wanda Sykes          Will.i.am    Carlos Saldanha   English
# 406             Eric Idle         Jim Carter         Kevin Lima   English
# 444         Julia Roberts      Oprah Winfrey        Gary Winick   English
# 448       Jesse McCartney    Lauren Gottlieb      Mike Mitchell   English
# 473        Charles Napier     Zahn McClarnon       Kelly Asbury   English
# 480         Penn Jillette       Russi Taylor        James Algar   English
# 500       Elizabeth Daily      Glenne Headly      George Miller   English
# 504        Jacques Perrin       Rie Miyazawa     Jacques Perrin    French
# 509           Nathan Lane      Niketa Calame       Roger Allers   English
# 583          Cheech Marin      George Carlin      John Lasseter   English
# 657           Aisha Tyler         Eric Lloyd    Michael Lembeck   English
# 714          Fred Willard        Amy Sedaris        Mark Dindal   English
# 756     Matthew Broderick     Frank Langella           Sam Fell   English
# 839          Frank Welker       Irene Bedard       Mike Gabriel   English
# 902        Kelsey Grammer  Bernadette Peters          Don Bluth   English
# ...                   ...                ...                ...       ...
# 2913        Gabriel Damon         Bill Erwin          Don Bluth   English
# 2943         Jerry Nelson     Steve Whitmire       Brian Henson   English
# 3028          Matt Prokop        Corbin Bleu       Kenny Ortega   English
# 3079        Gary Lockwood         Glenn Beck    Stanley Kubrick   English
# 3101       Richard Beymer       Eddie Albert        Ken Annakin   English
# 3107            Ron Moody          Jack Wild         Carol Reed   English
# 3109      Andrew Lawrence     Dabney Coleman       Chuck Sheetz   English
# 3142       Jane Krakowski       Willow Smith    Patricia Rozema   English
# 3179   Richard Farnsworth     Everett McGill        David Lynch   English
# 3280  Paul Michael Glaser    Rosalind Harris     Norman Jewison   English
# 3356           Jim Henson        Dom DeLuise      James Frawley   English
# 3359    Angela Cartwright   Nicholas Hammond        Robert Wise   English
# 3518       Marley Shelton    Jennifer Butler       Tim Chambers   English
# 3563          Paula Kelly     Eric Christmas        Robert Wise   English
# 3708          Herbert Lom   Catherine Schell      Blake Edwards   English
# 3723    Constance Shulman      Alice Playten      Maurice Joyce   English
# 3970        George Reeves    Thomas Mitchell     Victor Fleming   English
# 4024         Sofie Gråbøl   Romane Bohringer        Luc Jacquet    French
# 4062       Gregory Sierra       Victor Buono           Ted Post   English
# 4064          Eric Stuart         Lisa Ortiz    Kunihiko Yuyama  Japanese
# 4093       Jack Albertson    Julie Dawn Cole         Mel Stuart   English
# 4162           Kelly Reno         Hoyt Axton    Carroll Ballard   English
# 4185       M. Emmet Walsh          Sal Mineo         Don Taylor   English
# 4225         Deems Taylor                NaN        James Algar   English
# 4362        Paul Williams       Claude Akins    J. Lee Thompson   English
# 4427     Stanley Blystone     Fred Malatesta    Charles Chaplin   English
# 4591       Brian Whitaker      Jason Bateman      Kief Davidson   English
# 4725          Peter Breck     Edgar Buchanan           Joe Camp   English
# 4787        Jack Canfield         Eric Worre       Joe Kenemore   English
# 4874          Mark Hengst    Debra Lynn Hull  Rachel Goldenberg   English
#
#         country  aspect_ratio  title_year
# 35          USA          1.85      2013.0
# 41          USA          2.35      2011.0
# 43          USA          1.85      2010.0
# 58          USA          2.35      2008.0
# 91          USA          2.35      2004.0
# 119         USA          2.35      2007.0
# 209         USA          2.35      2014.0
# 238         USA          1.85      2001.0
# 277         USA          1.85      2009.0
# 297         USA          1.78      1996.0
# 298         USA          1.66      2000.0
# 323         USA          1.85      2015.0
# 338         USA          1.85      2003.0
# 353         USA          1.85      1999.0
# 362         USA          1.66      1998.0
# 384         USA          2.35      2011.0
# 406         USA          1.85      2000.0
# 444         USA          1.85      2006.0
# 448         USA          1.85      2011.0
# 473         USA          2.35      2002.0
# 480         USA          1.78      1999.0
# 500   Australia          1.85      1998.0
# 504      France          2.35      2009.0
# 509         USA          1.66      1994.0
# 583         USA          2.35      2006.0
# 657         USA          1.85      2002.0
# 714         USA          1.85      2005.0
# 756          UK          2.35      2008.0
# 839         USA          1.78      1995.0
# 902         USA          2.35      1997.0
# ...         ...           ...         ...
# 2913        USA          1.33      1988.0
# 2943        USA          1.85      1992.0
# 3028        USA          1.85      2008.0
# 3079         UK          2.20      1968.0
# 3101        USA          2.35      1962.0
# 3107         UK          2.35      1968.0
# 3109        USA          1.85      2001.0
# 3142        USA          1.85      2008.0
# 3179     France          2.35      1999.0
# 3280        USA          2.35      1971.0
# 3356         UK          1.85      1979.0
# 3359        USA          2.35      1965.0
# 3518        USA          2.35      2009.0
# 3563        USA          2.35      1971.0
# 3708         UK          2.35      1975.0
# 3723        USA          1.33      1999.0
# 3970        USA          1.37      1939.0
# 4024     France          1.85      2005.0
# 4062        USA          2.35      1970.0
# 4064      Japan          1.85      2000.0
# 4093        USA          1.33      1971.0
# 4162        USA          1.85      1979.0
# 4185        USA          2.35      1971.0
# 4225        USA          1.37      1940.0
# 4362        USA          2.35      1973.0
# 4427        USA          1.37      1936.0
# 4591    Denmark           NaN      2014.0
# 4725        USA          1.85      1974.0
# 4787        USA           NaN      2014.0
# 4874        USA          1.85      2008.0
#
# [112 rows x 15 columns]

# %% [markdown]
# ## Basic functions

# %% [markdown]
# There's a couple super helpful functions that help us work with our data.
#
# For sorting, we can use `.sort_values(by= )`, and pass in either a single string, or multiple strings in a list.
# <br>To flip the default order, change the `ascending= ` parameter to `False`

# %%
movies.sort_values(by=['imdb_score','gross'], ascending=False).head()
# Out:
#                         movie_title  imdb_score content_rating      budget  \
# 2765  Towering Inferno                      9.5            NaN         NaN
# 1937      The Shawshank Redemption          9.3              R  25000000.0
# 3466                 The Godfather          9.2              R   6000000.0
# 2824           Dekalog                      9.1          TV-MA         NaN
# 3207           Dekalog                      9.1          TV-MA         NaN
#
#             gross  duration       genres    actor_1_name     actor_2_name  \
# 2765          NaN      65.0       Comedy    Martin Short    Andrea Martin
# 1937   28341469.0     142.0  Crime|Drama  Morgan Freeman   Jeffrey DeMunn
# 3466  134821952.0     175.0  Crime|Drama       Al Pacino    Marlon Brando
# 2824     447093.0      55.0        Drama  Krystyna Janda  Olaf Lubaszenko
# 3207     447093.0      55.0        Drama  Krystyna Janda  Olaf Lubaszenko
#
#              actor_3_name         director_name language country  \
# 2765         Joe Flaherty        John Blanchard  English  Canada
# 1937           Bob Gunton        Frank Darabont  English     USA
# 3466        Robert Duvall  Francis Ford Coppola  English     USA
# 2824  Olgierd Lukaszewicz                   NaN   Polish  Poland
# 3207  Olgierd Lukaszewicz                   NaN   Polish  Poland
#
#       aspect_ratio  title_year
# 2765          1.33         NaN
# 1937          1.85      1994.0
# 3466          1.85      1972.0
# 2824          1.33         NaN
# 3207          1.33         NaN

# %% [markdown]
# We could also use the `.value_counts()` function to could how many observations there are for each category.
# <br>If we wanted relative frequencies (i.e. proportions) instead of absolute counts, we could change the `normalize=` parameter to `True`

# %%
movies.country.value_counts(normalize=True).head()
# Out:
# USA        0.755657
# UK         0.088924
# France     0.030568
# Canada     0.025010
# Germany    0.019254
# Name: country, dtype: float64

# %% [markdown]
# Finally, we can take basic summary measures, like the `.mean()` or `.sum()` of a column.

# %%
movies.budget.mean()
# Out:
# 39752620.436387606

# %% [markdown]
# ## Chaining

# %% [markdown]
# Chaining helps make our code more concise and readable.
#
# For example, if we wanted to combine some subsets with functions:

# %%
df1 = movies[movies.imdb_score > 8.5]
df2 = df1[df1.content_rating == 'PG']
df3 = df2.sort_values(by='duration',ascending=False)
df3.head()
# Out:
#                                           movie_title  imdb_score  \
# 2051  Star Wars: Episode V - The Empire Strikes Back          8.8
# 2373                                   Spirited Away          8.6
# 3024              Star Wars: Episode IV - A New Hope          8.7
# 4049                           It's a Wonderful Life          8.6
# 4526                                      Casablanca          8.6
#
#      content_rating      budget        gross  duration  \
# 2051             PG  18000000.0  290158751.0     127.0
# 2373             PG  19000000.0   10049886.0     125.0
# 3024             PG  11000000.0  460935665.0     125.0
# 4049             PG   3180000.0          NaN     118.0
# 4526             PG    950000.0          NaN      82.0
#
#                                   genres     actor_1_name      actor_2_name  \
# 2051     Action|Adventure|Fantasy|Sci-Fi    Harrison Ford       Kenny Baker
# 2373  Adventure|Animation|Family|Fantasy   Bunta Sugawara  Ryûnosuke Kamiki
# 3024     Action|Adventure|Fantasy|Sci-Fi    Harrison Ford     Peter Cushing
# 4049        Drama|Family|Fantasy|Romance       Donna Reed  Lionel Barrymore
# 4526                   Drama|Romance|War  Humphrey Bogart      Claude Rains
#
#          actor_3_name   director_name  language country  aspect_ratio  \
# 2051  Anthony Daniels  Irvin Kershner   English     USA          2.35
# 2373       Miyu Irino  Hayao Miyazaki  Japanese   Japan          1.85
# 3024      Kenny Baker    George Lucas   English     USA          2.35
# 4049  Thomas Mitchell     Frank Capra   English     USA          1.37
# 4526     Conrad Veidt  Michael Curtiz   English     USA          1.37
#
#       title_year
# 2051      1980.0
# 2373      2001.0
# 3024      1977.0
# 4049      1946.0
# 4526      1942.0

# %% [markdown]
# We could instead write the above as:

# %%
movies[movies.imdb_score > 8.5].loc[movies.content_rating == 'PG'].sort_values(by='duration',ascending=False).head()
# Out:
#                                           movie_title  imdb_score  \
# 2051  Star Wars: Episode V - The Empire Strikes Back          8.8
# 2373                                   Spirited Away          8.6
# 3024              Star Wars: Episode IV - A New Hope          8.7
# 4049                           It's a Wonderful Life          8.6
# 4526                                      Casablanca          8.6
#
#      content_rating      budget        gross  duration  \
# 2051             PG  18000000.0  290158751.0     127.0
# 2373             PG  19000000.0   10049886.0     125.0
# 3024             PG  11000000.0  460935665.0     125.0
# 4049             PG   3180000.0          NaN     118.0
# 4526             PG    950000.0          NaN      82.0
#
#                                   genres     actor_1_name      actor_2_name  \
# 2051     Action|Adventure|Fantasy|Sci-Fi    Harrison Ford       Kenny Baker
# 2373  Adventure|Animation|Family|Fantasy   Bunta Sugawara  Ryûnosuke Kamiki
# 3024     Action|Adventure|Fantasy|Sci-Fi    Harrison Ford     Peter Cushing
# 4049        Drama|Family|Fantasy|Romance       Donna Reed  Lionel Barrymore
# 4526                   Drama|Romance|War  Humphrey Bogart      Claude Rains
#
#          actor_3_name   director_name  language country  aspect_ratio  \
# 2051  Anthony Daniels  Irvin Kershner   English     USA          2.35
# 2373       Miyu Irino  Hayao Miyazaki  Japanese   Japan          1.85
# 3024      Kenny Baker    George Lucas   English     USA          2.35
# 4049  Thomas Mitchell     Frank Capra   English     USA          1.37
# 4526     Conrad Veidt  Michael Curtiz   English     USA          1.37
#
#       title_year
# 2051      1980.0
# 2373      2001.0
# 3024      1977.0
# 4049      1946.0
# 4526      1942.0

# %% [markdown]
# This works because each part of our code `returns` a dataframe, so we can keep tagging along functions instead of saving each step into a temporary variable.

# %% [markdown]
# **Try it out:** In one line, see if you can find the value counts of `content_rating` for movies with a gross revenue (`gross`) over `200000000` ($ 200 million)

# %%
movies[movies.gross > 200000000].content_rating.value_counts()
# Out:
# PG-13    97
# PG       49
# R        11
# G        10
# Name: content_rating, dtype: int64

# %% [markdown]
# # Practice w/ UFOs

# %% [markdown]
# Data sampled from the National UFO Reporting Center (NUFORC)
# <br>With your breakout groups, open up `ufo.csv` and answer the following questions:
#
# 1. Among the West Coast states (California, Oregon, and Washington), how long (on average) did the fireballs encounters last?
# 2. Which state saw the most encounters that lasted between 5 minutes to 1 hour?
# 3. There was one particularly interesting encounter on `2/11/2004 00:00` in West Palm Beach, Florida. What happened?
#
# <br>Hint: Break down each question into parts, and chain them back together. There's no particular 'right' way
# <br>To refer to the `shape` column, use `ufo['shape']` instead of `ufo.shape`, since the latter is a reserved attribute

# %%
ufo = pd.read_csv('ufo.csv')
ufo.head()
# Out:
#            datetime               city state country      shape  duration_sec  \
# 0   1/25/2014 22:00          tewksbury    ma      us      light           4.0
# 1   8/20/2004 22:27  lake in the hills    il      us   triangle         180.0
# 2   1/23/2009 19:00            slidell    la      us     sphere        7200.0
# 3  12/15/1994 21:00           alliance    oh      us  formation        1800.0
# 4   7/31/2011 21:00            milford    ct      us       oval          15.0
#
#     duration_hrs                                           comments  \
# 0          00:04  Green and red falling light over walgreens res...
# 1    2-3 minutes  On August 20&#442004 at exactly 10:25 to 10:27...
# 2        2 hours  Bright red&#44 green &#44 white and blue spher...
# 3       30 min +          Brightly Colored Orbs Over Portage County
# 4  10-15 seconds  Bright orange&#44 silent orb&#44 moving steadi...
#
#     latitude  longitude
# 0  42.610556  -71.234722
# 1  42.181667  -88.330278
# 2  30.275000  -89.781111
# 3  40.915278  -81.106111
# 4  41.222222  -73.056944

# %%
# 1
ufo.loc[ufo.state.isin(['ca','or','wa'])].loc[ufo['shape']=='fireball'].duration_sec.mean()
# Out:
# 238.88888888888889

# %%
# 2
ufo.loc[(ufo.duration_sec>=5*60) & (ufo.duration_sec<=60*60)].state.value_counts().head(1)
# Out:
# ca    392
# Name: state, dtype: int64

# %%
# 3
ufo.loc[ufo.datetime == '2/11/2004 00:00'].loc[ufo.city=='west palm beach'].comments.values[0]
# Out:
# 'BLINDING LIGHT LIFTED MY DOG AND TOOK OFF INTO SPACE'

# %% [markdown]
# # Groupby Objects

# %% [markdown]
# From before, we used `value_counts()` to get the number of movies per each content rating?

# %%
movies.content_rating.value_counts()
# Out:
# R            2118
# PG-13        1461
# PG            701
# Not Rated     116
# G             112
# Unrated        62
# Approved       55
# TV-14          30
# TV-MA          20
# X              13
# TV-PG          13
# TV-G           10
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-Y            1
# TV-Y7           1
# Name: content_rating, dtype: int64

# %% [markdown]
# This is a good summary statistic to examine the distribution of our dataset. But...
#
# <br>What if we want to know how movie performance differs by rating?
# <br>We need to apply some function (i.e. take the mean of revenue) **per each** content rating

# %%
movies_byRating = movies.groupby('content_rating')
type(movies_byRating)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %% [markdown]
# This creates a special **GroupBy object**.
#
# <br>For now, let's think of it like a *collection* of dataframes, seperated by each unique value from content rating (One group for `R`, `PG-13`, etc).
# <br>We can't easily render what the entire GroupBy object looks like, but we can pull out a particular group

# %%
movies_byRating

# %%
print(type(movies_byRating.get_group('PG')))
movies_byRating.get_group('PG').head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                   movie_title  imdb_score content_rating  \
# 7                                    Tangled          7.8             PG
# 9     Harry Potter and the Half-Blood Prince          7.5             PG
# 16  The Chronicles of Narnia: Prince Caspian          6.6             PG
# 33                       Alice in Wonderland          6.5             PG
# 38                 Oz the Great and Powerful          6.4             PG
#
#          budget        gross  duration  \
# 7   260000000.0  200807262.0     100.0
# 9   250000000.0  301956980.0     153.0
# 16  225000000.0  141614023.0     150.0
# 33  200000000.0  334185206.0     108.0
# 38  215000000.0  234903076.0     130.0
#
#                                                genres    actor_1_name  \
# 7   Adventure|Animation|Comedy|Family|Fantasy|Musi...    Brad Garrett
# 9                    Adventure|Family|Fantasy|Mystery    Alan Rickman
# 16                    Action|Adventure|Family|Fantasy  Peter Dinklage
# 33                           Adventure|Family|Fantasy     Johnny Depp
# 38                           Adventure|Family|Fantasy      Tim Holmes
#
#             actor_2_name    actor_3_name   director_name language country  \
# 7           Donna Murphy     M.C. Gainey    Nathan Greno  English     USA
# 9       Daniel Radcliffe    Rupert Grint     David Yates  English      UK
# 16  Pierfrancesco Favino  Damián Alcázar  Andrew Adamson  English     USA
# 33          Alan Rickman   Anne Hathaway      Tim Burton  English     USA
# 38            Mila Kunis    James Franco       Sam Raimi  English     USA
#
#     aspect_ratio  title_year
# 7           1.85      2010.0
# 9           2.35      2009.0
# 16          2.35      2008.0
# 33          1.85      2010.0
# 38          2.35      2013.0

# %% [markdown]
# When we apply **aggregation** functions to a `GroupBy` object, we get back averages for each column in the dataframe, **broken down** by content rating

# %%
movies_byRating.agg('mean')
# Out:
#                 imdb_score        budget         gross    duration  \
# content_rating
# Approved          7.325455  4.142475e+06  4.814586e+07  116.218182
# G                 6.529464  4.499913e+07  8.245516e+07   98.973214
# GP                6.916667  5.550000e+06  4.380000e+07  110.833333
# M                 6.840000  4.700000e+06  6.255445e+07  114.600000
# NC-17             6.542857  7.940714e+06  4.476870e+06  102.000000
# Not Rated         6.631034  4.479213e+06  2.090037e+06  110.318966
# PG                6.294437  4.838956e+07  7.295273e+07  104.857347
# PG-13             6.257495  5.425734e+07  6.564854e+07  111.365068
# Passed            7.166667  3.031421e+06  1.100354e+07  115.222222
# R                 6.527101  3.364755e+07  2.998365e+07  108.781767
# TV-14             7.250000  3.640000e+06           NaN   52.551724
# TV-G              6.920000  3.670000e+06           NaN   62.400000
# TV-MA             8.250000  3.400000e+07  4.470930e+05   47.350000
# TV-PG             7.353846  3.200000e+06           NaN   50.384615
# TV-Y              7.400000           NaN           NaN   30.000000
# TV-Y7             7.200000           NaN           NaN   30.000000
# Unrated           6.920968  5.092971e+06  4.302599e+06  102.790323
# X                 6.500000  3.338462e+06  1.865881e+07   92.615385
#
#                 aspect_ratio   title_year
# content_rating
# Approved            1.735818  1954.781818
# G                   1.962523  1995.892857
# GP                  2.024000  1970.666667
# M                   2.012000  1968.400000
# NC-17               1.855714  1994.571429
# Not Rated           2.101739  1997.504348
# PG                  2.061250  2000.392297
# PG-13               2.151456  2005.710472
# Passed              1.351111  1941.222222
# R                   2.118677  2002.950425
# TV-14               8.683103  2012.666667
# TV-G                2.023333  1997.500000
# TV-MA               7.652632          NaN
# TV-PG               4.492500  2010.333333
# TV-Y                1.330000          NaN
# TV-Y7               4.000000          NaN
# Unrated             2.110370  1990.354839
# X                   1.928462  1981.307692

# %% [markdown]
# If we were just to apply `.mean()` to the entire dataframe, we'd only get back one row with summaries for the entire dataset

# %%
pd.DataFrame(movies.mean(), columns=['Total']).T
# Out:
#        imdb_score        budget         gross    duration  aspect_ratio  \
# Total    6.442138  3.975262e+07  4.846841e+07  107.201074      2.220403
#
#         title_year
# Total  2002.470517

# %% [markdown]
# We've got other ways to aggregate the data too.
#
# Here, we're showing the mean, max, and min values of `imdb_score` by passing in multiple strings in a list to `.agg()`

# %%
movies_byRating['imdb_score'].agg(['mean', 'max', 'min', 'count'])
# Out:
#                     mean  max  min  count
# content_rating
# Approved        7.325455  8.9  4.1     55
# G               6.529464  8.6  1.6    112
# GP              6.916667  8.0  6.2      6
# M               6.840000  8.1  6.0      5
# NC-17           6.542857  7.6  4.6      7
# Not Rated       6.631034  8.9  2.0    116
# PG              6.294437  8.8  1.7    701
# PG-13           6.257495  9.0  1.9   1461
# Passed          7.166667  8.1  6.3      9
# R               6.527101  9.3  1.9   2118
# TV-14           7.250000  8.7  3.3     30
# TV-G            6.920000  8.4  4.8     10
# TV-MA           8.250000  9.1  7.0     20
# TV-PG           7.353846  8.4  5.5     13
# TV-Y            7.400000  7.4  7.4      1
# TV-Y7           7.200000  7.2  7.2      1
# Unrated         6.920968  8.7  3.2     62
# X               6.500000  7.9  4.0     13

# %% [markdown]
# The results of these groupby operations are all dataframes, check it out with the `type( )` operator
# This means we can start chaining together dataframe functions, for example `sort_values()`

# %% [markdown]
# **Try it out:** Break down median revenues by country, and sort them highest to lowest
# <br> If you finish early, try to show the same thing as above, but now *exclude* countries with less than 30 movies

# %%
# 1
movies.groupby(by='country').agg('median').sort_values(by='gross', ascending=False).head()
# Out:
#               imdb_score      budget       gross  duration  aspect_ratio  \
# country
# Taiwan              7.15  15000000.0  64340682.0     112.5          1.86
# Peru                5.40  45000000.0  57362581.0     110.0          1.85
# South Africa        6.25  17500000.0  45089048.0     100.5          1.85
# USA                 6.50  20000000.0  32178777.0     103.0          1.85
# New Zealand         7.30  25000000.0  30465398.0     108.0          2.35
#
#               title_year
# country
# Taiwan            2007.5
# Peru              1994.0
# South Africa      2011.5
# USA               2005.0
# New Zealand       2005.0

# %%
# 2
df = movies.groupby(by='country')['gross'].agg(['median', 'count']).sort_values(by='median', ascending=False)
df[df['count'] >= 30].reset_index()

# Note that we had to save the dataframe first to easily access the new indices for the mask/filter
# Also note that when we aggregated with multiple conditions, we first specified the column to aggregate on
# What happens if we didn't (i.e. first groupby, then aggregate, and filter columns last)? Try it out
# Out:
#      country      median  count
# 0        USA  32178777.0   3235
# 1    Germany  20978074.5     88
# 2  Australia  17356110.0     42
# 3         UK  13401683.0    364
# 4     Canada   6854620.0     72
# 5     France   4291965.0    121

# %% [markdown]
# ### Multilevel GroupBy

# %% [markdown]
# We can also group on multiple columns to get *all unique combinations* of those columns.
#
# <br> For example, we can see if the relationship between `content_rating` and `imdb_rating` differs across countries by using both as keys

# %%
movies_byCountryRating = movies.groupby(['country', 'content_rating'])

# %%
movies_byCountryRating['imdb_score'].agg('mean').sort_values(ascending=False).head()
# Out:
# country     content_rating
# Poland      TV-MA             9.1
# Italy       Approved          8.9
# Kyrgyzstan  PG-13             8.7
# Italy       TV-MA             8.7
#             PG-13             8.6
# Name: imdb_score, dtype: float64

# %% [markdown]
# # Summary

# %% [markdown]
# That's it for now!
#
# <br>Today you learned how to:
# - **Import** a dataset as a pandas object
# - Check out quick features, like `.head()`, `.shape`, and `.value_counts()`
# - The distinction between `pd.Series` and `pd.DataFrame` objects
# - **Filter** rows based on some condition
# - **Subset** columns to those we want

# %% [markdown]
# We also used special `GroupBy` objects to get specific drill-down insights by:
# <br>(1) first breaking out, or **grouping** a dataset based on some category, then
# <br>(2) **aggregating** information from each observation in that category
#
# <br> In practice, if we wanted to get a mean score, broken down by every value in a given column, we would do:
# <br>`df.groupby(by='group column').agg('mean').score_column`
