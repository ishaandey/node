# %% [markdown]
# ##  A Quick Review from W1

# %% [markdown]
# Before pulling any data, we've gotta import all the packages we need

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Now we can read in the data from a link OR from a file in the same directory

# %%
movies = pd.read_csv('imdb.csv')

# %% [markdown]
# Take a quick look at the data

# %%
movies.head()
# Out:
#                                          movie_title  imdb_score  \
# 0                                            Avatar          7.9
# 1          Pirates of the Caribbean: At World's End          7.1
# 2                                           Spectre          6.8
# 3                             The Dark Knight Rises          8.5
# 4  Star Wars: Episode VII - The Force Awakens    ...         7.1
#
#   content_rating       budget        gross  duration  \
# 0          PG-13  237000000.0  760505847.0     178.0
# 1          PG-13  300000000.0  309404152.0     169.0
# 2          PG-13  245000000.0  200074175.0     148.0
# 3          PG-13  250000000.0  448130642.0     164.0
# 4            NaN          NaN          NaN       NaN
#
#                             genres     actor_1_name      actor_2_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder  Joel David Moore
# 1         Action|Adventure|Fantasy      Johnny Depp     Orlando Bloom
# 2        Action|Adventure|Thriller  Christoph Waltz      Rory Kinnear
# 3                  Action|Thriller        Tom Hardy    Christian Bale
# 4                      Documentary      Doug Walker        Rob Walker
#
#            actor_3_name      director_name language country  aspect_ratio  \
# 0             Wes Studi      James Cameron  English     USA          1.78
# 1        Jack Davenport     Gore Verbinski  English     USA          2.35
# 2      Stephanie Sigman         Sam Mendes  English      UK          2.35
# 3  Joseph Gordon-Levitt  Christopher Nolan  English     USA          2.35
# 4                   NaN        Doug Walker      NaN     NaN           NaN
#
#    title_year
# 0      2009.0
# 1      2007.0
# 2      2015.0
# 3      2012.0
# 4         NaN

# %%
movies.shape
# Out:
# (5043, 15)

# %% [markdown]
# There's a lot of columns- could we get a full list?

# %%
movies.columns
# Out:
# Index(['movie_title', 'imdb_score', 'content_rating', 'budget', 'gross',
#        'duration', 'genres', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'director_name', 'language', 'country', 'aspect_ratio', 'title_year'],
#       dtype='object')

# %% [markdown]
# How many movies does each director have on IMDB?

# %%
movies.director_name.value_counts()
# Out:
# Steven Spielberg       26
# Woody Allen            22
# Martin Scorsese        20
# Clint Eastwood         20
# Ridley Scott           17
#                        ..
# Eric Nicholas           1
# Demian Lichtenstein     1
# William Phillips        1
# Dan Scanlon             1
# Gérard Krawczyk         1
# Name: director_name, Length: 2398, dtype: int64

# %% [markdown]
# What are the top 3 longest movies on the list?

# %%
movies.sort_values(by='duration', ascending=False).head()
# Out:
#                     movie_title  imdb_score content_rating       budget  \
# 1710       Trapped                      8.2            NaN          NaN
# 2466        Carlos                      7.7      Not Rated          NaN
# 1501       Blood In, Blood Out          8.0              R   35000000.0
# 1144             Heaven's Gate          6.8              R   44000000.0
# 3311  The Legend of Suriyothai          6.6              R  400000000.0
#
#           gross  duration                              genres  \
# 1710        NaN     511.0                Crime|Drama|Thriller
# 2466   145118.0     334.0      Biography|Crime|Drama|Thriller
# 1501  4496583.0     330.0                         Crime|Drama
# 1144  1500000.0     325.0             Adventure|Drama|Western
# 3311   454255.0     300.0  Action|Adventure|Drama|History|War
#
#                actor_1_name              actor_2_name  \
# 1710  Ólafur Darri Ólafsson  Ingvar Eggert Sigurðsson
# 2466          Edgar Ramírez      Nora von Waldstätten
# 1501           Delroy Lindo             Jesse Borrego
# 1144           Jeff Bridges             Sam Waterston
# 3311   Sarunyu Wongkrachang      Chatchai Plengpanich
#
#                  actor_3_name        director_name   language   country  \
# 1710  Björn Hlynur Haraldsson                  NaN  Icelandic   Iceland
# 2466      Katharina Schüttler                  NaN    English    France
# 1501             Raymond Cruz      Taylor Hackford    English       USA
# 1144         Isabelle Huppert       Michael Cimino    English       USA
# 3311          Mai Charoenpura  Chatrichalerm Yukol       Thai  Thailand
#
#       aspect_ratio  title_year
# 1710         16.00         NaN
# 2466          2.35         NaN
# 1501          1.66      1993.0
# 1144          2.35      1980.0
# 3311          1.85      2001.0

# %% [markdown]
# # Pandas Foundations

# %% [markdown]
# ## Series vs. Dataframes

# %% [markdown]
# So far we've been referring to *2 dimensional* tables using the `pd.DataFrame` object
# <br>An individual column (or row), is *1 dimensional*. We call this a `pd.Series` object

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# We can access a series using either form: `df.column` OR `df['column']`

# %%
print(type(movies.imdb_score))
print(movies.imdb_score)
# Out:
# <class 'pandas.core.series.Series'>
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 5038    7.7
# 5039    7.5
# 5040    6.3
# 5041    6.3
# 5042    6.6
# Name: imdb_score, Length: 5043, dtype: float64

# %%
print(type(movies['imdb_score']))
print(movies['imdb_score'])
# Out:
# <class 'pandas.core.series.Series'>
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 5038    7.7
# 5039    7.5
# 5040    6.3
# 5041    6.3
# 5042    6.6
# Name: imdb_score, Length: 5043, dtype: float64

# %% [markdown]
# To select a **row** as a series, we can use `df.iloc[]` and a specific row number (its index)

# %%
print(type(movies.iloc[3]))
movies.iloc[3]
# Out:
# <class 'pandas.core.series.Series'>
# movie_title       The Dark Knight Rises
# imdb_score                           8.5
# content_rating                     PG-13
# budget                           2.5e+08
# gross                        4.48131e+08
# duration                             164
# genres                   Action|Thriller
# actor_1_name                   Tom Hardy
# actor_2_name              Christian Bale
# actor_3_name        Joseph Gordon-Levitt
# director_name          Christopher Nolan
# language                         English
# country                              USA
# aspect_ratio                        2.35
# title_year                          2012
# Name: 3, dtype: object

# %% [markdown]
# ## Subsetting Columns

# %% [markdown]
# Subsetting and filtering is one of the most important, yet confusing topics when getting started.
# <br>As we go along, feel free to run the code part by part to see what's going on in each step. `type()` is also a great tool here

# %% [markdown]
# Lets take a look at a smaller set of columns, say just the movie_title and each actor & director name

# %%
movies[['movie_title','actor_1_name','actor_2_name','actor_3_name','director_name']] # Note TWO square brackets
# Out:
#                                             movie_title     actor_1_name  \
# 0                                               Avatar       CCH Pounder
# 1             Pirates of the Caribbean: At World's End       Johnny Depp
# 2                                              Spectre   Christoph Waltz
# 3                                The Dark Knight Rises         Tom Hardy
# 4     Star Wars: Episode VII - The Force Awakens    ...      Doug Walker
# ...                                                 ...              ...
# 5038                           Signed Sealed Delivered       Eric Mabius
# 5039                         The Following                   Natalie Zea
# 5040                              A Plague So Pleasant       Eva Boehnke
# 5041                                  Shanghai Calling         Alan Ruck
# 5042                                 My Date with Drew       John August
#
#           actor_2_name          actor_3_name      director_name
# 0     Joel David Moore             Wes Studi      James Cameron
# 1        Orlando Bloom        Jack Davenport     Gore Verbinski
# 2         Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3       Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4           Rob Walker                   NaN        Doug Walker
# ...                ...                   ...                ...
# 5038     Daphne Zuniga          Crystal Lowe        Scott Smith
# 5039     Valorie Curry         Sam Underwood                NaN
# 5040     Maxwell Moody        David Chandler   Benjamin Roberds
# 5041     Daniel Henney           Eliza Coupe        Daniel Hsia
# 5042  Brian Herzlinger              Jon Gunn           Jon Gunn
#
# [5043 rows x 5 columns]

# %% [markdown]
# Why did we use two square brackets? What we're doing is passing a `list` to the subset function.
# <br> Pandas `DataFrame` objects know that whenever we place `[]` after it, we're looking to do some sort of filtering operation
# <br><br> This ends up being pretty helpful, because it gives us a shortcut to create similar subsets over and over

# %%
actor_cols = ['actor_1_name','actor_2_name','actor_3_name']
movies[actor_cols]
# Out:
#          actor_1_name      actor_2_name          actor_3_name
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 5038      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 5039      Natalie Zea     Valorie Curry         Sam Underwood
# 5040      Eva Boehnke     Maxwell Moody        David Chandler
# 5041        Alan Ruck     Daniel Henney           Eliza Coupe
# 5042      John August  Brian Herzlinger              Jon Gunn
#
# [5043 rows x 3 columns]

# %%
movies[['movie_title']+actor_cols]
# Out:
#                                             movie_title     actor_1_name  \
# 0                                               Avatar       CCH Pounder
# 1             Pirates of the Caribbean: At World's End       Johnny Depp
# 2                                              Spectre   Christoph Waltz
# 3                                The Dark Knight Rises         Tom Hardy
# 4     Star Wars: Episode VII - The Force Awakens    ...      Doug Walker
# ...                                                 ...              ...
# 5038                           Signed Sealed Delivered       Eric Mabius
# 5039                         The Following                   Natalie Zea
# 5040                              A Plague So Pleasant       Eva Boehnke
# 5041                                  Shanghai Calling         Alan Ruck
# 5042                                 My Date with Drew       John August
#
#           actor_2_name          actor_3_name
# 0     Joel David Moore             Wes Studi
# 1        Orlando Bloom        Jack Davenport
# 2         Rory Kinnear      Stephanie Sigman
# 3       Christian Bale  Joseph Gordon-Levitt
# 4           Rob Walker                   NaN
# ...                ...                   ...
# 5038     Daphne Zuniga          Crystal Lowe
# 5039     Valorie Curry         Sam Underwood
# 5040     Maxwell Moody        David Chandler
# 5041     Daniel Henney           Eliza Coupe
# 5042  Brian Herzlinger              Jon Gunn
#
# [5043 rows x 4 columns]

# %% [markdown]
# Quick point of confusion: Check out the difference between `df['column']` vs `df[['column']]` ( try it out w/ `movies` below! )
# <br><br> The former creates a *series*, since the input is just one *string*. The latter creates a *dataframe*, since the input is a *list* of columns.

# %%
movies['content_rating']
# Out:
# 0       PG-13
# 1       PG-13
# 2       PG-13
# 3       PG-13
# 4         NaN
#         ...
# 5038      NaN
# 5039    TV-14
# 5040      NaN
# 5041    PG-13
# 5042       PG
# Name: content_rating, Length: 5043, dtype: object

# %%
movies[['content_rating']]
# Out:
#      content_rating
# 0             PG-13
# 1             PG-13
# 2             PG-13
# 3             PG-13
# 4               NaN
# ...             ...
# 5038            NaN
# 5039          TV-14
# 5040            NaN
# 5041          PG-13
# 5042             PG
#
# [5043 rows x 1 columns]

# %% [markdown]
# ## Filtering Rows With Conditions

# %% [markdown]
# Another common task is to filter rows based upon some criteria we have. We could:
# 1. Compare floats
# 2. Match strings
# 3. Check against multiple elements

# %%
movies[movies.imdb_score>8]
# Out:
#                                  movie_title  imdb_score content_rating  \
# 3                     The Dark Knight Rises          8.5          PG-13
# 17                             The Avengers          8.1          PG-13
# 27               Captain America: Civil War          8.2          PG-13
# 43                              Toy Story 3          8.3              G
# 58                                   WALL·E          8.4              G
# ...                                      ...         ...            ...
# 4924                         Butterfly Girl          8.7            NaN
# 4937              A Charlie Brown Christmas          8.4           TV-G
# 4945                   The Brain That Sings          8.2            NaN
# 4972  Peace, Propaganda & the Promised Land          8.3            NaN
# 5001                         The Last Waltz          8.2             PG
#
#            budget        gross  duration  \
# 3     250000000.0  448130642.0     164.0
# 17    220000000.0  623279547.0     173.0
# 27    250000000.0  407197282.0     147.0
# 43    200000000.0  414984497.0     103.0
# 58    180000000.0  223806889.0      98.0
# ...           ...          ...       ...
# 4924     180000.0          NaN      78.0
# 4937     150000.0          NaN      25.0
# 4945     125000.0          NaN      62.0
# 4972      70000.0          NaN      80.0
# 5001          NaN     321952.0     117.0
#
#                                          genres       actor_1_name  \
# 3                               Action|Thriller          Tom Hardy
# 17                      Action|Adventure|Sci-Fi    Chris Hemsworth
# 27                      Action|Adventure|Sci-Fi  Robert Downey Jr.
# 43    Adventure|Animation|Comedy|Family|Fantasy          Tom Hanks
# 58            Adventure|Animation|Family|Sci-Fi  John Ratzenberger
# ...                                         ...                ...
# 4924                                Documentary      Abigail Evans
# 4937                    Animation|Comedy|Family      Peter Robbins
# 4945                         Documentary|Family                NaN
# 4972                                Documentary       Noam Chomsky
# 5001                          Documentary|Music        Ringo Starr
#
#             actor_2_name          actor_3_name      director_name language  \
# 3         Christian Bale  Joseph Gordon-Levitt  Christopher Nolan  English
# 17     Robert Downey Jr.    Scarlett Johansson        Joss Whedon  English
# 27    Scarlett Johansson           Chris Evans      Anthony Russo  English
# 43     John Ratzenberger           Don Rickles        Lee Unkrich  English
# 58          Fred Willard           Jeff Garlin     Andrew Stanton  English
# ...                  ...                   ...                ...      ...
# 4924        Stacie Evans          Emily Gorell          Cary Bell  English
# 4937       Bill Melendez      Christopher Shea      Bill Melendez  English
# 4945                 NaN                   NaN    Amal Al-Agroobi   Arabic
# 4972       Seth Ackerman        Arik Ascherman         Sut Jhally  English
# 5001          Levon Helm             Bob Dylan    Martin Scorsese  English
#
#                    country  aspect_ratio  title_year
# 3                      USA          2.35      2012.0
# 17                     USA          1.85      2012.0
# 27                     USA          2.35      2016.0
# 43                     USA          1.85      2010.0
# 58                     USA          2.35      2008.0
# ...                    ...           ...         ...
# 4924                   USA           NaN      2014.0
# 4937                   USA          1.33      1965.0
# 4945  United Arab Emirates           NaN      2013.0
# 4972                   USA           NaN      2004.0
# 5001                   USA          1.85      1978.0
#
# [253 rows x 15 columns]

# %%
movies[movies.content_rating=='G']
# Out:
#                                             movie_title  imdb_score  \
# 35                                 Monsters University          7.3
# 41                                              Cars 2          6.3
# 43                                         Toy Story 3          8.3
# 58                                              WALL·E          8.4
# 91                                   The Polar Express          6.6
# ...                                                 ...         ...
# 4427                                      Modern Times          8.6
# 4591                              A Lego Brickumentary          6.8
# 4725                                             Benji          6.1
# 4787  Rise of the Entrepreneur: The Search for a Bet...         8.2
# 4874                             Sunday School Musical          2.5
#
#      content_rating       budget        gross  duration  \
# 35                G  200000000.0  268488329.0     104.0
# 41                G  200000000.0  191450875.0     106.0
# 43                G  200000000.0  414984497.0     103.0
# 58                G  180000000.0  223806889.0      98.0
# 91                G  165000000.0     665426.0     100.0
# ...             ...          ...          ...       ...
# 4427              G    1500000.0     163245.0      87.0
# 4591              G    1000000.0     100240.0      93.0
# 4725              G     500000.0   39552600.0      86.0
# 4787              G     450000.0          NaN      52.0
# 4874              G          NaN          NaN      93.0
#
#                                          genres       actor_1_name  \
# 35    Adventure|Animation|Comedy|Family|Fantasy      Steve Buscemi
# 41      Adventure|Animation|Comedy|Family|Sport       Joe Mantegna
# 43    Adventure|Animation|Comedy|Family|Fantasy          Tom Hanks
# 58            Adventure|Animation|Family|Sci-Fi  John Ratzenberger
# 91           Adventure|Animation|Family|Fantasy          Tom Hanks
# ...                                         ...                ...
# 4427                        Comedy|Drama|Family   Paulette Goddard
# 4591                                Documentary        G.W. Krauss
# 4725                   Adventure|Family|Romance     Frances Bavier
# 4787                                Documentary        Bob Proctor
# 4874                              Drama|Musical  Dustin Fitzsimons
#
#             actor_2_name     actor_3_name      director_name language  \
# 35          Tyler Labine       Sean Hayes        Dan Scanlon  English
# 41    Thomas Kretschmann     Eddie Izzard      John Lasseter  English
# 43     John Ratzenberger      Don Rickles        Lee Unkrich  English
# 58          Fred Willard      Jeff Garlin     Andrew Stanton  English
# 91          Eddie Deezen    Peter Scolari    Robert Zemeckis  English
# ...                  ...              ...                ...      ...
# 4427    Stanley Blystone   Fred Malatesta    Charles Chaplin  English
# 4591      Brian Whitaker    Jason Bateman      Kief Davidson  English
# 4725         Peter Breck   Edgar Buchanan           Joe Camp  English
# 4787       Jack Canfield       Eric Worre       Joe Kenemore  English
# 4874         Mark Hengst  Debra Lynn Hull  Rachel Goldenberg  English
#
#       country  aspect_ratio  title_year
# 35        USA          1.85      2013.0
# 41        USA          2.35      2011.0
# 43        USA          1.85      2010.0
# 58        USA          2.35      2008.0
# 91        USA          2.35      2004.0
# ...       ...           ...         ...
# 4427      USA          1.37      1936.0
# 4591  Denmark           NaN      2014.0
# 4725      USA          1.85      1974.0
# 4787      USA           NaN      2014.0
# 4874      USA          1.85      2008.0
#
# [112 rows x 15 columns]

# %% [markdown]
# We'll use the `.isin()` operator to match against a group. Remember, `.isin()` accepts a `list` only

# %%
movies[movies.country.isin(['India','Sri Lanka', 'Pakistan', 'Bangladesh'])]
# Out:
#                               movie_title  imdb_score content_rating  \
# 1056                               Earth          7.8        Unrated
# 1329            Baahubali: The Beginning          8.4            NaN
# 2349                           Ramanujan          7.0            NaN
# 3075              Kabhi Alvida Naa Kehna          6.0              R
# 3085                           Housefull          5.3            NaN
# 3208                              Krrish          6.3      Not Rated
# 3273                               Kites          6.0            NaN
# 3276                    Jab Tak Hai Jaan          6.9      Not Rated
# 3344                     My Name Is Khan          8.0          PG-13
# 3348                     Namastey London          7.3            NaN
# 3350             Yeh Jawaani Hai Deewani          6.9      Not Rated
# 3510                          Veer-Zaara          7.9            NaN
# 3665                         Khiladi 786          4.3      Not Rated
# 3685                     Rang De Basanti          8.4      Not Rated
# 3695                       Dum Maaro Dum          6.2              R
# 3789                   Gandhi, My Father          7.4            NaN
# 3834                               Barfi          7.1            NaN
# 3866                               Fugly          4.7            NaN
# 3870                             Airlift          8.5            NaN
# 3877                                 Paa          7.2            NaN
# 4160                Lage Raho Munna Bhai          8.2          PG-13
# 4299              Hum To Mohabbat Karega          2.8            NaN
# 4305                      Roadside Romeo          5.3             PG
# 4351           ABCD (Any Body Can Dance)          6.4      Not Rated
# 4365                               Vaalu          5.1            NaN
# 4385                        The Lunchbox          7.8             PG
# 4397                 Dil Jo Bhi Kahey...          5.1            NaN
# 4471                      Neal 'N' Nikki          3.3            NaN
# 4490                     Monsoon Wedding          7.4              R
# 4528  Rocket Singh: Salesman of the Year          7.5            NaN
# 4572                                Fiza          6.2            NaN
# 4593        Chocolate: Deep Dark Secrets          4.8            NaN
# 4609                   Karachi se Lahore          7.0            NaN
# 4724                   Faith Connections          7.0            NaN
# 4837              Ayurveda: Art of Being          7.6            NaN
#
#            budget       gross  duration                              genres  \
# 1056          NaN    528972.0     110.0                   Drama|Romance|War
# 1329   18026148.0   6498000.0     159.0  Action|Adventure|Drama|Fantasy|War
# 2349          NaN         NaN     153.0             Biography|Drama|History
# 3075  700000000.0   3275443.0     193.0                               Drama
# 3085          NaN   1165104.0     144.0                              Comedy
# 3208   10000000.0         NaN     168.0     Action|Adventure|Romance|Sci-Fi
# 3273  600000000.0   1602466.0      90.0       Action|Drama|Romance|Thriller
# 3276    7217600.0   3047539.0     176.0                       Drama|Romance
# 3344   12000000.0   4018695.0     128.0            Adventure|Drama|Thriller
# 3348          NaN   1207007.0     128.0                Comedy|Drama|Romance
# 3350          NaN   3827466.0     160.0        Comedy|Drama|Musical|Romance
# 3510    7000000.0   2921738.0     192.0               Drama|Musical|Romance
# 3665          NaN    352684.0     141.0                       Action|Comedy
# 3685          NaN   2197331.0     157.0        Comedy|Drama|History|Romance
# 3695          NaN    563699.0     128.0         Action|Crime|Drama|Thriller
# 3789          NaN    240425.0     136.0             Biography|Drama|History
# 3834          NaN         NaN       NaN                      Comedy|Romance
# 3866          NaN         NaN     134.0                      Drama|Thriller
# 3870    4400000.0         NaN     130.0   Action|Drama|History|Thriller|War
# 3877  150000000.0    199228.0     133.0                        Comedy|Drama
# 4160  120000000.0         NaN     144.0                Comedy|Drama|Romance
# 4299          NaN         NaN       NaN      Action|Comedy|Romance|Thriller
# 4305          NaN     55202.0      93.0     Animation|Comedy|Family|Romance
# 4351          NaN     95236.0     160.0                       Drama|Musical
# 4365  150000000.0         NaN     155.0                      Comedy|Romance
# 4385    1000000.0   4231500.0     104.0                       Drama|Romance
# 4397   70000000.0    129319.0       NaN                             Romance
# 4471    1500000.0    100358.0      97.0              Comedy|Musical|Romance
# 4490    7000000.0  13876974.0     114.0                Comedy|Drama|Romance
# 4528          NaN         NaN     150.0                        Comedy|Drama
# 4572    1000000.0    610991.0     167.0                       Drama|Romance
# 4593    1500000.0     49000.0     160.0                            Thriller
# 4609    1000000.0         NaN       NaN                       Comedy|Family
# 4724     550000.0         NaN     115.0         Biography|Documentary|Drama
# 4837     300000.0     16892.0     102.0                         Documentary
#
#              actor_1_name            actor_2_name  \
# 1056          Nandita Das          Gulshan Grover
# 1329     Tamannaah Bhatia          Anushka Shetty
# 2349        Mani Bharathi          Michael Lieber
# 3075       Shah Rukh Khan            John Abraham
# 3085         Arjun Rampal             Boman Irani
# 3208     Naseeruddin Shah                   Rekha
# 3273         Bárbara Mori  Steven Michael Quezada
# 3276       Shah Rukh Khan            Katrina Kaif
# 3344       Shah Rukh Khan          Jimmy Shergill
# 3348         Katrina Kaif           Clive Standen
# 3350        Ranbir Kapoor           Madhuri Dixit
# 3510       Shah Rukh Khan            Preity Zinta
# 3665                 Asin      Mithun Chakraborty
# 3685          Anupam Kher       Steven Mackintosh
# 3695    Abhishek Bachchan            Bipasha Basu
# 3789       Akshaye Khanna         Bhoomika Chawla
# 3834                Bhama                 Diganth
# 3866       Jimmy Shergill              Sana Saeed
# 3870          Nimrat Kaur         Sameer Ali Khan
# 3877          Vidya Balan       Abhishek Bachchan
# 4160          Vidya Balan             Sanjay Dutt
# 4299       Karisma Kapoor              Bobby Deol
# 4305        Saif Ali Khan           Sanjay Mishra
# 4351      Lauren Gottlieb                    Remo
# 4365      Hansika Motwani       T.R. Silambarasan
# 4385  Nawazuddin Siddiqui             Nimrat Kaur
# 4397     Annabelle Wallis                 Revathy
# 4471    Abhishek Bachchan             Uday Chopra
# 4490     Naseeruddin Shah           Randeep Hooda
# 4528        Ranbir Kapoor        Shazahn Padamsee
# 4572       Karisma Kapoor          Manoj Bajpayee
# 4593        Emraan Hashmi             Anil Kapoor
# 4609          Rasheed Naz             Ayesha Omar
# 4724           Bhole Baba         Pant Shirt Baba
# 4837                  NaN                     NaN
#
#                        actor_3_name            director_name language  \
# 1056                  Eric Peterson              Deepa Mehta    Hindi
# 1329                        Prabhas           S.S. Rajamouli   Telugu
# 2349                  Kevin McGowan        Gnana Rajasekaran  English
# 3075                   Preity Zinta              Karan Johar    Hindi
# 3085               Riteish Deshmukh               Sajid Khan    Hindi
# 3208                  Sharat Saxena            Rakesh Roshan    Hindi
# 3273                     Kabir Bedi              Anurag Basu  English
# 3276                    Vic Waghorn              Yash Chopra    Hindi
# 3344          Christopher B. Duncan              Karan Johar    Hindi
# 3348               Riteish Deshmukh      Vipul Amrutlal Shah    Hindi
# 3350              Aditya Roy Kapoor             Ayan Mukerji    Hindi
# 3510                    Anupam Kher              Yash Chopra    Hindi
# 3665                   Johnny Lever          Ashish R. Mohan    Hindi
# 3685                       Madhavan  Rakeysh Omprakash Mehra    Hindi
# 3695                        Prateik              Rohan Sippy    Hindi
# 3789               Darshan Jariwala         Feroz Abbas Khan    Hindi
# 3834                     Dileep Raj                   Shekar  Kannada
# 3866                 Dimple Kapadia           Kabir Sadanand    Hindi
# 3870                    Purab Kohli               Raja Menon    Hindi
# 3877                   Paresh Rawal                 R. Balki    Hindi
# 4160                 Jimmy Shergill          Rajkumar Hirani    Hindi
# 4299                  Shakti Kapoor              Kundan Shah    Hindi
# 4305                  Javed Jaffrey            Jugal Hansraj    Hindi
# 4351                    Prabhudheva                     Remo    Hindi
# 4365                   Brahmanandam            Vijay Chandar    Tamil
# 4385                  Lillete Dubey             Ritesh Batra    Hindi
# 4397                Bhoomika Chawla            Romesh Sharma  English
# 4471                Samantha McLeod             Arjun Sablok  English
# 4490                  Lillete Dubey                Mira Nair    Hindi
# 4528                    Gauhar Khan              Shimit Amin    Hindi
# 4572                   Jaya Bhaduri           Khalid Mohamed    Hindi
# 4593                   Sunil Shetty          Vivek Agnihotri    Hindi
# 4609                   Javed Sheikh             Wajahat Rauf     Urdu
# 4724  Shriman Umeshanad Brahmachari                Pan Nalin    Hindi
# 4837                            NaN                Pan Nalin  English
#
#        country  aspect_ratio  title_year
# 1056     India           NaN      1998.0
# 1329     India          1.85      2015.0
# 2349     India          2.35      2014.0
# 3075     India          2.35      2006.0
# 3085     India           NaN      2010.0
# 3208     India          2.35      2006.0
# 3273     India           NaN      2010.0
# 3276     India          2.35      2012.0
# 3344     India          2.35      2010.0
# 3348     India           NaN      2007.0
# 3350     India           NaN      2013.0
# 3510     India          2.35      2004.0
# 3665     India           NaN      2012.0
# 3685     India          2.35      2006.0
# 3695     India           NaN      2011.0
# 3789     India          2.35      2007.0
# 3834     India           NaN      2013.0
# 3866     India           NaN      2014.0
# 3870     India          2.35      2016.0
# 3877     India          2.35      2009.0
# 4160     India          2.35      2006.0
# 4299     India           NaN      2000.0
# 4305     India          2.35      2008.0
# 4351     India           NaN      2013.0
# 4365     India           NaN      2015.0
# 4385     India          2.35      2013.0
# 4397     India           NaN      2005.0
# 4471     India          2.35      2005.0
# 4490     India          1.85      2001.0
# 4528     India           NaN      2009.0
# 4572     India          2.35      2000.0
# 4593     India           NaN      2005.0
# 4609  Pakistan           NaN      2015.0
# 4724     India          1.85      2013.0
# 4837     India          1.85      2001.0

# %% [markdown]
# ### Masking

# %% [markdown]
# What's going on under the hood? With each argument, we're passing a list of `True` and `False`, for whether or not a given *row* matches the criteria.
# <br><br>With the above examples:

# %%
movies.content_rating == 'PG'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5038    False
# 5039    False
# 5040    False
# 5041    False
# 5042     True
# Name: content_rating, Length: 5043, dtype: bool

# %%
movies[   movies.content_rating == 'PG'   ]
# Out:
#                                     movie_title  imdb_score content_rating  \
# 7                                      Tangled          7.8             PG
# 9       Harry Potter and the Half-Blood Prince          7.5             PG
# 16    The Chronicles of Narnia: Prince Caspian          6.6             PG
# 33                         Alice in Wonderland          6.5             PG
# 38                   Oz the Great and Powerful          6.4             PG
# ...                                         ...         ...            ...
# 4962              The Lost Skeleton of Cadavra          7.0             PG
# 4963                    Dude, Where's My Dog?!          3.2             PG
# 4977                             Super Size Me          7.3             PG
# 5001                            The Last Waltz          8.2             PG
# 5042                         My Date with Drew          6.6             PG
#
#            budget        gross  duration  \
# 7     260000000.0  200807262.0     100.0
# 9     250000000.0  301956980.0     153.0
# 16    225000000.0  141614023.0     150.0
# 33    200000000.0  334185206.0     108.0
# 38    215000000.0  234903076.0     130.0
# ...           ...          ...       ...
# 4962      40000.0     110536.0      90.0
# 4963      20000.0          NaN      82.0
# 4977      65000.0   11529368.0     100.0
# 5001          NaN     321952.0     117.0
# 5042       1100.0      85222.0      90.0
#
#                                                  genres     actor_1_name  \
# 7     Adventure|Animation|Comedy|Family|Fantasy|Musi...     Brad Garrett
# 9                      Adventure|Family|Fantasy|Mystery     Alan Rickman
# 16                      Action|Adventure|Family|Fantasy   Peter Dinklage
# 33                             Adventure|Family|Fantasy      Johnny Depp
# 38                             Adventure|Family|Fantasy       Tim Holmes
# ...                                                 ...              ...
# 4962                               Comedy|Horror|Sci-Fi    Fay Masterson
# 4963                                             Family  Kevin P. Farley
# 4977                           Comedy|Documentary|Drama  Chemeeka Walker
# 5001                                  Documentary|Music      Ringo Starr
# 5042                                        Documentary      John August
#
#               actor_2_name       actor_3_name     director_name language  \
# 7             Donna Murphy        M.C. Gainey      Nathan Greno  English
# 9         Daniel Radcliffe       Rupert Grint       David Yates  English
# 16    Pierfrancesco Favino     Damián Alcázar    Andrew Adamson  English
# 33            Alan Rickman      Anne Hathaway        Tim Burton  English
# 38              Mila Kunis       James Franco         Sam Raimi  English
# ...                    ...                ...               ...      ...
# 4962            Brian Howe      Larry Blamire     Larry Blamire  English
# 4963     Gabriela Castillo  Brandon Middleton  Stephen Langford  English
# 4977        Amanda Kearsan   Amelia Giancarlo   Morgan Spurlock  English
# 5001            Levon Helm          Bob Dylan   Martin Scorsese  English
# 5042      Brian Herzlinger           Jon Gunn          Jon Gunn  English
#
#      country  aspect_ratio  title_year
# 7        USA          1.85      2010.0
# 9         UK          2.35      2009.0
# 16       USA          2.35      2008.0
# 33       USA          1.85      2010.0
# 38       USA          2.35      2013.0
# ...      ...           ...         ...
# 4962     USA          1.85      2001.0
# 4963     USA          1.85      2014.0
# 4977     USA          1.78      2004.0
# 5001     USA          1.85      1978.0
# 5042     USA          1.85      2004.0
#
# [701 rows x 15 columns]

# %% [markdown]
# ## Chaining

# %% [markdown]
# Chaining is super helpful in making our code more concise and readable
#
# For example, if we wanted to combine some of the previous conditions and subsets:

# %%
df1 = movies[movies.imdb_score > 8]
df2 = df1[df1.content_rating == 'PG']
df3 = df2.sort_values(by='duration',ascending=False)
df3.head()
# Out:
#                         movie_title  imdb_score content_rating      budget  \
# 2088                        Gandhi          8.1             PG  22000000.0
# 2644            Lawrence of Arabia          8.4             PG  15000000.0
# 3048                  Barry Lyndon          8.1             PG  11000000.0
# 4066  The Bridge on the River Kwai          8.2             PG   3000000.0
# 1504            Lion of the Desert          8.4             PG  35000000.0
#
#            gross  duration                                 genres  \
# 2088         NaN     240.0                Biography|Drama|History
# 2644   6000000.0     227.0  Adventure|Biography|Drama|History|War
# 3048         NaN     184.0            Adventure|Drama|History|War
# 4066  27200000.0     161.0                    Adventure|Drama|War
# 1504         NaN     156.0            Biography|Drama|History|War
#
#         actor_1_name     actor_2_name  actor_3_name         director_name  \
# 2088  Candice Bergen      Amrish Puri  John Gielgud  Richard Attenborough
# 2644    Claude Rains      José Ferrer  Jack Hawkins            David Lean
# 3048     Ryan O'Neal   Steven Berkoff  Hardy Krüger       Stanley Kubrick
# 4066  William Holden  Sessue Hayakawa  Jack Hawkins            David Lean
# 1504     Oliver Reed      Rod Steiger  John Gielgud       Moustapha Akkad
#
#      language country  aspect_ratio  title_year
# 2088  English      UK          2.35      1982.0
# 2644  English      UK          2.20      1962.0
# 3048  English      UK          1.66      1975.0
# 4066  English      UK          2.35      1957.0
# 1504  English   Libya          2.35      1980.0

# %% [markdown]
# We could instead write the above as:

# %%
movies.loc[movies.imdb_score > 8]
# Out:
#                                  movie_title  imdb_score content_rating  \
# 3                     The Dark Knight Rises          8.5          PG-13
# 17                             The Avengers          8.1          PG-13
# 27               Captain America: Civil War          8.2          PG-13
# 43                              Toy Story 3          8.3              G
# 58                                   WALL·E          8.4              G
# ...                                      ...         ...            ...
# 4924                         Butterfly Girl          8.7            NaN
# 4937              A Charlie Brown Christmas          8.4           TV-G
# 4945                   The Brain That Sings          8.2            NaN
# 4972  Peace, Propaganda & the Promised Land          8.3            NaN
# 5001                         The Last Waltz          8.2             PG
#
#            budget        gross  duration  \
# 3     250000000.0  448130642.0     164.0
# 17    220000000.0  623279547.0     173.0
# 27    250000000.0  407197282.0     147.0
# 43    200000000.0  414984497.0     103.0
# 58    180000000.0  223806889.0      98.0
# ...           ...          ...       ...
# 4924     180000.0          NaN      78.0
# 4937     150000.0          NaN      25.0
# 4945     125000.0          NaN      62.0
# 4972      70000.0          NaN      80.0
# 5001          NaN     321952.0     117.0
#
#                                          genres       actor_1_name  \
# 3                               Action|Thriller          Tom Hardy
# 17                      Action|Adventure|Sci-Fi    Chris Hemsworth
# 27                      Action|Adventure|Sci-Fi  Robert Downey Jr.
# 43    Adventure|Animation|Comedy|Family|Fantasy          Tom Hanks
# 58            Adventure|Animation|Family|Sci-Fi  John Ratzenberger
# ...                                         ...                ...
# 4924                                Documentary      Abigail Evans
# 4937                    Animation|Comedy|Family      Peter Robbins
# 4945                         Documentary|Family                NaN
# 4972                                Documentary       Noam Chomsky
# 5001                          Documentary|Music        Ringo Starr
#
#             actor_2_name          actor_3_name      director_name language  \
# 3         Christian Bale  Joseph Gordon-Levitt  Christopher Nolan  English
# 17     Robert Downey Jr.    Scarlett Johansson        Joss Whedon  English
# 27    Scarlett Johansson           Chris Evans      Anthony Russo  English
# 43     John Ratzenberger           Don Rickles        Lee Unkrich  English
# 58          Fred Willard           Jeff Garlin     Andrew Stanton  English
# ...                  ...                   ...                ...      ...
# 4924        Stacie Evans          Emily Gorell          Cary Bell  English
# 4937       Bill Melendez      Christopher Shea      Bill Melendez  English
# 4945                 NaN                   NaN    Amal Al-Agroobi   Arabic
# 4972       Seth Ackerman        Arik Ascherman         Sut Jhally  English
# 5001          Levon Helm             Bob Dylan    Martin Scorsese  English
#
#                    country  aspect_ratio  title_year
# 3                      USA          2.35      2012.0
# 17                     USA          1.85      2012.0
# 27                     USA          2.35      2016.0
# 43                     USA          1.85      2010.0
# 58                     USA          2.35      2008.0
# ...                    ...           ...         ...
# 4924                   USA           NaN      2014.0
# 4937                   USA          1.33      1965.0
# 4945  United Arab Emirates           NaN      2013.0
# 4972                   USA           NaN      2004.0
# 5001                   USA          1.85      1978.0
#
# [253 rows x 15 columns]

# %%
movies[movies.imdb_score > 8].loc[movies.content_rating == 'PG'].sort_values(by='duration',ascending=False).head()
# Out:
#                         movie_title  imdb_score content_rating      budget  \
# 2088                        Gandhi          8.1             PG  22000000.0
# 2644            Lawrence of Arabia          8.4             PG  15000000.0
# 3048                  Barry Lyndon          8.1             PG  11000000.0
# 4066  The Bridge on the River Kwai          8.2             PG   3000000.0
# 1504            Lion of the Desert          8.4             PG  35000000.0
#
#            gross  duration                                 genres  \
# 2088         NaN     240.0                Biography|Drama|History
# 2644   6000000.0     227.0  Adventure|Biography|Drama|History|War
# 3048         NaN     184.0            Adventure|Drama|History|War
# 4066  27200000.0     161.0                    Adventure|Drama|War
# 1504         NaN     156.0            Biography|Drama|History|War
#
#         actor_1_name     actor_2_name  actor_3_name         director_name  \
# 2088  Candice Bergen      Amrish Puri  John Gielgud  Richard Attenborough
# 2644    Claude Rains      José Ferrer  Jack Hawkins            David Lean
# 3048     Ryan O'Neal   Steven Berkoff  Hardy Krüger       Stanley Kubrick
# 4066  William Holden  Sessue Hayakawa  Jack Hawkins            David Lean
# 1504     Oliver Reed      Rod Steiger  John Gielgud       Moustapha Akkad
#
#      language country  aspect_ratio  title_year
# 2088  English      UK          2.35      1982.0
# 2644  English      UK          2.20      1962.0
# 3048  English      UK          1.66      1975.0
# 4066  English      UK          2.35      1957.0
# 1504  English   Libya          2.35      1980.0

# %% [markdown]
# This works because each part of our code `returns` a dataframe, so we can keep applying as many dataframe functions as we want at once.
#
# Try it out: In one line, see if you can find the value counts of `content_rating` for movies with a gross revenue (`gross`) over `200000000` ($ 200 million)

# %%
movies[movies.gross > 200000000].content_rating.value_counts()
# Out:
# PG-13    97
# PG       49
# R        11
# G        10
# Name: content_rating, dtype: int64

# %% [markdown]
# # Practice w/ UFOs

# %% [markdown]
# Data sampled from the National UFO Reporting Center (NUFORC.
# <br>With your breakout groups, open up `ufo.csv` and answer the following questions:
#
# 1. Among the West Coast states (California, Oregon, and Washington), how long (on average) did the fireballs encounters last?
# 2. Which state saw the most encounters that lasted between 5 minutes to 1 hour?
# 3. There was one particularly interesting encounter on `2/11/2004 00:00` in West Palm Beach, Florida. What happened?
#
# <br>Hint: Break down each question into parts, and chain them back together
# <br>There are many ways of arriving at the answer, there's no particular 'right' way

# %%
ufo = pd.read_csv('ufo.csv')
ufo.head()
# Out:
#            datetime               city state country      shape  duration_sec  \
# 0   1/25/2014 22:00          tewksbury    ma      us      light           4.0
# 1   8/20/2004 22:27  lake in the hills    il      us   triangle         180.0
# 2   1/23/2009 19:00            slidell    la      us     sphere        7200.0
# 3  12/15/1994 21:00           alliance    oh      us  formation        1800.0
# 4   7/31/2011 21:00            milford    ct      us       oval          15.0
#
#     duration_hrs                                           comments  \
# 0          00:04  Green and red falling light over walgreens res...
# 1    2-3 minutes  On August 20&#442004 at exactly 10:25 to 10:27...
# 2        2 hours  Bright red&#44 green &#44 white and blue spher...
# 3       30 min +          Brightly Colored Orbs Over Portage County
# 4  10-15 seconds  Bright orange&#44 silent orb&#44 moving steadi...
#
#     latitude  longitude
# 0  42.610556  -71.234722
# 1  42.181667  -88.330278
# 2  30.275000  -89.781111
# 3  40.915278  -81.106111
# 4  41.222222  -73.056944

# %%
ufo.loc[ufo.state.isin(['ca','or','wa'])].loc[ufo['shape']=='fireball'].duration_sec.mean()
# Out:
# 238.88888888888889

# %%
ufo.loc[ufo.duration_sec >= 300].loc[ufo.duration_sec <= 3600].state.value_counts().head(1)
# Out:
# ca    392
# Name: state, dtype: int64

# %%
ufo.loc[ufo.datetime == '2/11/2004 00:00'].loc[ufo.city == 'west palm beach'].comments.values[0]
# Out:
# 'BLINDING LIGHT LIFTED MY DOG AND TOOK OFF INTO SPACE'

# %% [markdown]
# # Groupby Objects

# %% [markdown]
# From before: How would we get the number of movies in this dataset that received each possible content rating?

# %%
movies.content_rating.value_counts()
# Out:
# R            2118
# PG-13        1461
# PG            701
# Not Rated     116
# G             112
# Unrated        62
# Approved       55
# TV-14          30
# TV-MA          20
# X              13
# TV-PG          13
# TV-G           10
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-Y7           1
# TV-Y            1
# Name: content_rating, dtype: int64

# %% [markdown]
# This is a good summary statistic to examine the distribution of our dataset. But...
#
# What if we want to know how movie performance differs by rating?

# %%
movies_byRating = movies.groupby(by='content_rating')
type(movies_byRating)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# This creates a special **GroupBy object**.
#
# For now, let's think of it like a *collection* of dataframes, seperated by each unique value from content rating (One group for `R`, `PG-13`, etc).
#
# We can't easily see what the entire GroupBy object looks like, but we can get a specific group

# %%
movies_byRating

# %%
print(type(movies_byRating.get_group('PG')))
movies_byRating.get_group('PG').head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                   movie_title  imdb_score content_rating  \
# 7                                    Tangled          7.8             PG
# 9     Harry Potter and the Half-Blood Prince          7.5             PG
# 16  The Chronicles of Narnia: Prince Caspian          6.6             PG
# 33                       Alice in Wonderland          6.5             PG
# 38                 Oz the Great and Powerful          6.4             PG
#
#          budget        gross  duration  \
# 7   260000000.0  200807262.0     100.0
# 9   250000000.0  301956980.0     153.0
# 16  225000000.0  141614023.0     150.0
# 33  200000000.0  334185206.0     108.0
# 38  215000000.0  234903076.0     130.0
#
#                                                genres    actor_1_name  \
# 7   Adventure|Animation|Comedy|Family|Fantasy|Musi...    Brad Garrett
# 9                    Adventure|Family|Fantasy|Mystery    Alan Rickman
# 16                    Action|Adventure|Family|Fantasy  Peter Dinklage
# 33                           Adventure|Family|Fantasy     Johnny Depp
# 38                           Adventure|Family|Fantasy      Tim Holmes
#
#             actor_2_name    actor_3_name   director_name language country  \
# 7           Donna Murphy     M.C. Gainey    Nathan Greno  English     USA
# 9       Daniel Radcliffe    Rupert Grint     David Yates  English      UK
# 16  Pierfrancesco Favino  Damián Alcázar  Andrew Adamson  English     USA
# 33          Alan Rickman   Anne Hathaway      Tim Burton  English     USA
# 38            Mila Kunis    James Franco       Sam Raimi  English     USA
#
#     aspect_ratio  title_year
# 7           1.85      2010.0
# 9           2.35      2009.0
# 16          2.35      2008.0
# 33          1.85      2010.0
# 38          2.35      2013.0

# %% [markdown]
# When we apply **aggregation** functions to a `GroupBy` object, i.e. `mean()`, we get back averages for the other columns **broken down** by each content rating

# %%
movies_byRating.mean()
# Out:
#                 imdb_score        budget         gross    duration  \
# content_rating
# Approved          7.325455  4.142475e+06  4.814586e+07  116.218182
# G                 6.529464  4.499913e+07  8.245516e+07   98.973214
# GP                6.916667  5.550000e+06  4.380000e+07  110.833333
# M                 6.840000  4.700000e+06  6.255445e+07  114.600000
# NC-17             6.542857  7.940714e+06  4.476870e+06  102.000000
# Not Rated         6.631034  4.479213e+06  2.090037e+06  110.318966
# PG                6.294437  4.838956e+07  7.295273e+07  104.857347
# PG-13             6.257495  5.425734e+07  6.564854e+07  111.365068
# Passed            7.166667  3.031421e+06  1.100354e+07  115.222222
# R                 6.527101  3.364755e+07  2.998365e+07  108.781767
# TV-14             7.250000  3.640000e+06           NaN   52.551724
# TV-G              6.920000  3.670000e+06           NaN   62.400000
# TV-MA             8.250000  3.400000e+07  4.470930e+05   47.350000
# TV-PG             7.353846  3.200000e+06           NaN   50.384615
# TV-Y              7.400000           NaN           NaN   30.000000
# TV-Y7             7.200000           NaN           NaN   30.000000
# Unrated           6.920968  5.092971e+06  4.302599e+06  102.790323
# X                 6.500000  3.338462e+06  1.865881e+07   92.615385
#
#                 aspect_ratio   title_year
# content_rating
# Approved            1.735818  1954.781818
# G                   1.962523  1995.892857
# GP                  2.024000  1970.666667
# M                   2.012000  1968.400000
# NC-17               1.855714  1994.571429
# Not Rated           2.101739  1997.504348
# PG                  2.061250  2000.392297
# PG-13               2.151456  2005.710472
# Passed              1.351111  1941.222222
# R                   2.118677  2002.950425
# TV-14               8.683103  2012.666667
# TV-G                2.023333  1997.500000
# TV-MA               7.652632          NaN
# TV-PG               4.492500  2010.333333
# TV-Y                1.330000          NaN
# TV-Y7               4.000000          NaN
# Unrated             2.110370  1990.354839
# X                   1.928462  1981.307692

# %% [markdown]
# If we were just to apply `.mean()` to the entire dataframe, we'd only get back one row with summaries for the entire dataset

# %%
pd.DataFrame(movies.mean()).T
# Out:
#    imdb_score        budget         gross    duration  aspect_ratio  \
# 0    6.442138  3.975262e+07  4.846841e+07  107.201074      2.220403
#
#     title_year
# 0  2002.470517

# %% [markdown]
# We've got other ways to aggregate the data too.
#
# Here, we're showing the mean, max, and min values of `imdb_score` by subsetting to only that column before applying a special `.agg()` function to aggregate the groupby object

# %%
movies_byRating.agg(['mean','max','min','count'])['imdb_score']
# Out:
#    content_rating      mean  max  min  count
# 0        Approved  7.325455  8.9  4.1     55
# 1               G  6.529464  8.6  1.6    112
# 2              GP  6.916667  8.0  6.2      6
# 3               M  6.840000  8.1  6.0      5
# 4           NC-17  6.542857  7.6  4.6      7
# 5       Not Rated  6.631034  8.9  2.0    116
# 6              PG  6.294437  8.8  1.7    701
# 7           PG-13  6.257495  9.0  1.9   1461
# 8          Passed  7.166667  8.1  6.3      9
# 9               R  6.527101  9.3  1.9   2118
# 10          TV-14  7.250000  8.7  3.3     30
# 11           TV-G  6.920000  8.4  4.8     10
# 12          TV-MA  8.250000  9.1  7.0     20
# 13          TV-PG  7.353846  8.4  5.5     13
# 14           TV-Y  7.400000  7.4  7.4      1
# 15          TV-Y7  7.200000  7.2  7.2      1
# 16        Unrated  6.920968  8.7  3.2     62
# 17              X  6.500000  7.9  4.0     13

# %%
# The count should align with the size of the PG-13 group from above
movies_byRating.get_group('PG-13').shape
# Out:
# (1461, 15)

# %% [markdown]
# The results of these groupby operations are all dataframes, check it out with the `type( )` operator
# This means we can start chaining together dataframe functions, for example `sort_values()`
#
# <br> Try it out: Break down median revenues by country, and sort them highest to lowest
# <br> If you finish early, try to show the same thing as above, but now *exclude* countries with less than 30 movies

# %%
movies.groupby(by='country').agg('median').sort_values(by='gross',ascending=False).head()
# Out:
#               imdb_score      budget       gross  duration  aspect_ratio  \
# country
# Taiwan              7.15  15000000.0  64340682.0     112.5          1.86
# Peru                5.40  45000000.0  57362581.0     110.0          1.85
# South Africa        6.25  17500000.0  45089048.0     100.5          1.85
# USA                 6.50  20000000.0  32178777.0     103.0          1.85
# New Zealand         7.30  25000000.0  30465398.0     108.0          2.35
#
#               title_year
# country
# Taiwan            2007.5
# Peru              1994.0
# South Africa      2011.5
# USA               2005.0
# New Zealand       2005.0

# %%
df = movies.groupby(by='country').agg(['median','count'])['gross'].sort_values(by='median', ascending=False)
df[df['count'] >= 30]
# Out:
#                median  count
# country
# USA        32178777.0   3235
# Germany    20978074.5     88
# Australia  17356110.0     42
# UK         13401683.0    364
# Canada      6854620.0     72
# France      4291965.0    121

# %% [markdown]
# We can also group on multiple columns to get *all unique combinations* of those columns.
#
# <br> For example, we can see if the relationship between `content_rating` and `imdb_rating` differs across countries.

# %%
movies_byCountryRating = movies.groupby(by=['country', 'content_rating'])

# %%
movies_byCountryRating.size()
# Out:
# country       content_rating
# Afghanistan   PG-13              1
# Argentina     R                  3
#               Unrated            1
# Aruba         R                  1
# Australia     G                  2
#                                 ..
# USA           Unrated           38
#               X                 12
# West Germany  M                  1
#               PG                 1
#               R                  1
# Length: 176, dtype: int64

# %% [markdown]
# To get a specific group, we must now pass a `tuple`, since there are two "keys", or layers on which we've grouped by

# %%
movies_byCountryRating.get_group( ('USA','PG-13')   ).head()
# Out:
#                                  movie_title  imdb_score content_rating  \
# 0                                    Avatar          7.9          PG-13
# 1  Pirates of the Caribbean: At World's End          7.1          PG-13
# 3                     The Dark Knight Rises          8.5          PG-13
# 5                               John Carter          6.6          PG-13
# 6                              Spider-Man 3          6.2          PG-13
#
#         budget        gross  duration                           genres  \
# 0  237000000.0  760505847.0     178.0  Action|Adventure|Fantasy|Sci-Fi
# 1  300000000.0  309404152.0     169.0         Action|Adventure|Fantasy
# 3  250000000.0  448130642.0     164.0                  Action|Thriller
# 5  263700000.0   73058679.0     132.0          Action|Adventure|Sci-Fi
# 6  258000000.0  336530303.0     156.0         Action|Adventure|Romance
#
#    actor_1_name      actor_2_name          actor_3_name      director_name  \
# 0   CCH Pounder  Joel David Moore             Wes Studi      James Cameron
# 1   Johnny Depp     Orlando Bloom        Jack Davenport     Gore Verbinski
# 3     Tom Hardy    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 5  Daryl Sabara   Samantha Morton          Polly Walker     Andrew Stanton
# 6  J.K. Simmons      James Franco         Kirsten Dunst          Sam Raimi
#
#   language country  aspect_ratio  title_year
# 0  English     USA          1.78      2009.0
# 1  English     USA          2.35      2007.0
# 3  English     USA          2.35      2012.0
# 5  English     USA          2.35      2012.0
# 6  English     USA          2.35      2007.0

# %%
movies_byCountryRating['imdb_score'].mean()
# Out:
# country       content_rating
# Afghanistan   PG-13             7.400000
# Argentina     R                 7.600000
#               Unrated           7.200000
# Aruba         R                 4.800000
# Australia     G                 6.300000
#                                   ...
# USA           Unrated           6.936842
#               X                 6.466667
# West Germany  M                 6.000000
#               PG                7.400000
#               R                 8.400000
# Name: imdb_score, Length: 176, dtype: float64

# %% [markdown]
# # Summary

# %% [markdown]
# That's it for now!
#
# <br>Today you learned how to:
# - **Import** a dataset as a pandas object
# - Check out quick features, like `.head()`, `.shape`, and `.value_counts()`
# - The distinction between `pd.Series` and `pd.DataFrame` objects
# - **Filter** rows based on some condition
# - **Subset** columns to those we want

# %% [markdown]
# We also used special `GroupBy` objects to get specific drilled-down insights by:
# <br>(1) first **disassociate** a dataset based on some criteria, then
# <br>(2) get some **aggregate** value, such that the new dataframe has one row for every value we grouped by
#
# <br> In practice, if we wanted to get a mean score, broken down by every value in a given column, we would do:
# <br>`df.groupby(by='group column').agg('mean').score_column`
