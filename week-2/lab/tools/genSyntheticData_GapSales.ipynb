# %% [markdown]
# ### Data Documentation:
# <br>**Description**: Synthetic dataset from Gap Inc., representing individual purchases from Q1 FY2020. Each row is a unique item purchased in an order
# <br><br>
#
# | **Feature** | **Description**    | **Sample Value**  |
# | ------- | -----------    | ------------- |
# | OrderID | Unique order identifier per transaction | Q13Fa20xP   |
# | ItemID  | 8-digit identifier per item in order | 513-817-239 |
# | ItemName | Name of item associated with item identifier | Blue khakis |
# | ItemSize | Size of item | XS, X, M, L, X, XL |
# | Collection | Which part of store | Mens Denim, Mens Outerwear, Mens Tees, Kids Tees, |
# | PriceTag | Listed price of item | $9.95 |
# | ClearanceType | Type of clearance | Retail, Clearance, Final Sale |
# | DiscountType | If Gap Card rewards was used | Reward points, Promotion, GapCash, Other |
# | TimeStamp | Date purchased as YYYYMMDD | 2020-02-05 |
# | BranchID | 4-digit store number| #1253, #0531, #4176 |
# | StoreName | Physical location of store | San Diego, CA |
# | OnlinePurchase | Was the purchase done online  |1 if yes, 0 otherwise |
#
# <br>

# %% [markdown]
# ## Workflow:
#
#
# **for products:**
# (have list of products)
# (map each product to randomly generated ID)
# (map each product to collection)
# (map each product to business segment)
# (map each product to price)
#     * price selected from dist
#
# **for stores:**
# (gen list of storeIDs)
# (map storeID to location)
#
# <br><br>
# (gen list of orderIDs from n_orders)
# create diff order lengths, using poisson distribution w/ lambda=1
#
# **for each order:**
#     - choose a timestamp (rng)
#     - choose online or not (rng)
#
#     - choose storeID (& corresponding location) (by binom)
#     - choose discountType (by dist)
#
#     - randomly select k products, where k is the order length
#     - for each product:
#         - randomly assign ClearanceType, and subtract corresponding number from Price Tag
#
#
# append all to a dataframe

# %%
import pandas as pd
import numpy as np
np.seed = 137

from sklearn.datasets import make_classification
from sklearn.datasets import make_regression

import random 
import string 

import matplotlib.pyplot as plt
import seaborn as sns

execution_ct = 0

# %%
def genClassesByFreq(n_obs=100, classes=[], freq=[]):
    RNGs = np.random.uniform(0,1,n_obs)
    cutoffs = np.array(freq).cumsum()
    labels = np.digitize(RNGs, cutoffs, right=True)

    labels_dict = dict(zip(range(len(classes)), classes))
    data = np.vectorize(dict(labels_dict).get)(labels)
    return data

# %%
def genStringID(length=8, chars=string.ascii_uppercase + string.digits): 
    """
    Generate random strings of length str_length, choosing from chars list only
    """
    return ''.join(random.choice(chars) for x in range(length))

def genFloatID(n_sections=2): 
    """
    Generate random float id with n sections seperated by hyphen, each section of length 'length'
    """
    return '-'.join(str(np.random.randint(100,999)) for x in range(n_sections))
   
def generateIDs(n_obs, n_unique=10, freq=[], id_type='string', verbose=False, **kwargs):
    """
    Generate IDs of array length n_obs, with k classes, with desired frequency given as weights to each class
    Can make either float or string ID
    """
    if 'str' in id_type:
        classes = [genStringID(chars="1234567890QZFSCWZTKRD",**kwargs) for i in range(n_unique)]
    else: 
        classes = [genFloatID(**kwargs) for i in range(n_unique)]
        
    data = genClassesByFreq(n_obs, classes, freq)
    if verbose:
        print(pd.Series(data).value_counts())
    
    return data
# pd.Series(generateIDs(n_obs=100, n_unique=10, freq=[.5,.4,.06, .04], id_type='string')).value_counts()

# %%
def random_dates(start, end, n=10):
    """
    Generate random TS between start / end date
    """
    start_u = start.value//10**9
    end_u = end.value//10**9

    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit='s')

Q1_start = pd.to_datetime('2020-01-01')
Q1_end = pd.to_datetime('2020-03-31')

# %% [markdown]
# ## Make Product Data

# %%
# ORIGIN = pd.read_clipboard()
products = ORIGIN.copy()

# %%
products.columns=['ProductName','Collection','Brand','PriceIndex','RelPopularity']
products.sample(5)
# Out:
#                                   ProductName    Collection            Brand  \
# 29                  Lightly Used Boxer Briefs   Accessories              Gap
# 6   White Camisole with Regina George Cutouts  Women's Tops  Banana Republic
# 45           Mom-Bought-Me-These Brown Slacks  Kids Bottoms              Gap
# 17              Pink Polo by Kanye Plain Tee     Men's Tops              Gap
# 40              Father's Day Dark Dress Socks   Accessories  Banana Republic
#
#     PriceIndex  RelPopularity
# 29           1          0.001
# 6            2          0.010
# 45           2          0.100
# 17           2          0.001
# 40           1          0.010

# %%
def mapPricesFromIndex(x=1):
    """
    x  target range	distribution
    1  $1-20	    gaussian(10,3)
    2  $30-60	    gaussian(45,4)
    3  $90+	        exponential(20)+80
    """
    if x==1:
        return 1+np.abs(np.random.gamma(3,3))
    elif x==2:
        return np.abs(np.random.normal(45,10))
    elif x==3:
        return 60+5*np.random.gamma(2,7)
    else:
        return 9999.

# %%
products['Price'] = np.around(products.PriceIndex.apply(mapPricesFromIndex),decimals=2)
products['RelFreq'] = 4+np.log10(products.RelPopularity)+np.abs(np.random.normal(0,.15,size=len(products)))
products['ProductID'] = [genFloatID(3)[1:] for i in range(len(products.Price))]

# %%
products = products[['ProductID','ProductName','Collection','Brand', 'Price', 'RelFreq']]
products.sample(5)
# Out:
#      ProductID                                  ProductName     Collection  \
# 19  57-583-745      Super Skinny Fit with GapFlex Max Jeans     Denim Shop
# 37  00-893-818      Beach Week Linen Button Down, Off-White     Men's Tops
# 39  47-230-154               SpaceX Branded Socks, by NASA™      Kids Tops
# 8   10-966-490      Tan Slacks for Serious Press Conference  Men's Bottoms
# 28  91-951-829  Wrinkled Gray Sweatpants for Work-From-Home  Men's Bottoms
#
#               Brand   Price   RelFreq
# 19              Gap   37.12  3.113620
# 37  Banana Republic   64.38  2.191056
# 39              Gap    5.99  2.005600
# 8   Banana Republic  138.83  3.026137
# 28              Gap    8.51  3.065687

# %%
products['SampleWeight'] = (products.RelFreq**1.3) / (products.RelFreq**1.3).sum()
products
# Out:
#      ProductID                                        ProductName  \
# 0   31-880-165               Edgar Allen Poe's Snotty Hankerchief
# 1   77-374-679                            Baby Shoes, Never Worn
# 2   36-682-186                                 Adam Levine Choker
# 3   10-113-846                          My Wife Borat Graphic Tee
# 4   75-833-369      Checkered Cloth Mask with Drinking Straw Hole
# 5   93-552-710  Acid-Washed Low-Rise Jeans with LSD-tab-sized ...
# 6   77-870-213          White Camisole with Regina George Cutouts
# 7   82-161-128                          Mullet-Cut Midi Fur Skirt
# 8   10-966-490            Tan Slacks for Serious Press Conference
# 9   97-602-297        Tan Suit Jacket for Casual Press Conference
# 10  54-774-509                    I Stan Fast Fashion Graphic Tee
# 11  86-602-300     Let's Reinforce Gender Stereotypes Graphic Tee
# 12  95-782-461                    Mr. Peanut-Style Top Hat (#RIP)
# 13  43-780-794                         Blue Light Blocker Monocle
# 14  55-469-816  Let's-Wear-White-After-Labor-Day 3/4 Sleeve Bl...
# 15  77-682-180                      I'm A Potato Graphic Crop Tee
# 16  50-597-783      Fourth of July Flag Tank, Pre-Mustard Stained
# 17  67-804-387                      Pink Polo by Kanye Plain Tee
# 18  73-142-641            Sunday Church on Zoom Children's Khakis
# 19  57-583-745            Super Skinny Fit with GapFlex Max Jeans
# 20  52-602-718       My roommate looked good in this Denim Jacket
# 21  26-434-264                                  Bootleg Boot Cut
# 22  65-100-438                         N-A-P Logo Branded Sweater
# 23  04-992-436                      Iota Delta Kappa Olive Chinos
# 24  08-230-912                              Scratchy Woolen Socks
# 25  79-411-382     Beautiful Mind Tweed Jacket with Shoulder Pads
# 26  54-133-899          Wireframe Glasses, Without plastic lenses
# 27  29-948-151                 Sun.png Summer Collection Sundress
# 28  91-951-829        Wrinkled Gray Sweatpants for Work-From-Home
# 29  64-360-768                          Lightly Used Boxer Briefs
# 30  66-878-360         Rainbow Collection Camouflage Camisole Top
# 31  05-574-428               Hello, World! JavaScript Graphic Tee
# 32  61-852-890                            (Marginal) Utility Belt
# 33  09-875-876      Comfortable Jeans, Exclusive to Size(s): XXXS
# 34  50-500-575  Old inventory we couldn't sell StretchFit Legg...
# 35  24-868-681               The Conjuring Graphic Tee Collection
# 36  45-570-528     That-Hoodie-You'll-Wear-to-Every-Class Sweater
# 37  00-893-818            Beach Week Linen Button Down, Off-White
# 38  43-105-886              Vintage Surfboard Graphic Tee, Cotton
# 39  47-230-154                     SpaceX Branded Socks, by NASA™
# 40  37-327-246                      Father's Day Dark Dress Socks
# 41  64-654-502              Plain White T's Designer Graphic Tees
# 42  29-761-664                        Dishwasher-Safe Jean Shorts
# 43  60-444-763  Human Rights (except for the children who make...
# 44  76-558-812  Yes-I-am-Experiencing-Menopause-Thank-You-for-...
# 45  64-692-585                   Mom-Bought-Me-These Brown Slacks
# 46  22-487-163                Tobey Maguire Spiderman Graphic Tee
# 47  10-561-512             Environmentally Unconcious Jean Shorts
#
#          Collection            Brand   Price   RelFreq  SampleWeight
# 0       Accessories  Banana Republic    6.56  1.121818      0.008366
# 1       Accessories              Gap   10.63  2.055596      0.018384
# 2       Accessories              Gap   11.39  1.157228      0.008711
# 3        Men's Tops              Gap   50.95  2.046423      0.018278
# 4       Accessories              Gap    7.31  3.234156      0.033137
# 5   Women's Bottoms  Banana Republic  109.48  3.216709      0.032905
# 6      Women's Tops  Banana Republic   53.60  2.141382      0.019388
# 7   Women's Bottoms  Banana Republic   88.94  2.167520      0.019696
# 8     Men's Bottoms  Banana Republic  138.83  3.026137      0.030394
# 9        Men's Tops  Banana Republic   97.93  3.037863      0.030547
# 10        Kids Tops         Gap Kids   13.20  3.154514      0.032080
# 11        Kids Tops         Gap Kids    1.82  3.076588      0.031054
# 12      Accessories  Banana Republic   12.41  1.047310      0.007651
# 13      Accessories              Gap   19.23  2.156792      0.019569
# 14     Women's Tops  Banana Republic  109.11  2.257052      0.020760
# 15     Women's Tops              Gap   11.58  2.196776      0.020042
# 16       Men's Tops              Gap   20.51  2.079939      0.018668
# 17       Men's Tops              Gap   46.74  1.324411      0.010381
# 18        Kids Tops              Gap   48.76  2.092836      0.018818
# 19       Denim Shop              Gap   37.12  3.113620      0.031541
# 20       Denim Shop              Gap   30.53  3.096239      0.031312
# 21       Denim Shop              Gap   39.35  2.077511      0.018639
# 22        Kids Tops              Gap   55.81  3.169207      0.032275
# 23    Men's Bottoms  Banana Republic   39.49  2.029569      0.018082
# 24      Accessories  Banana Republic    7.70  1.053104      0.007706
# 25       Men's Tops  Banana Republic   73.08  1.011961      0.007317
# 26      Accessories  Banana Republic    4.66  2.138260      0.019351
# 27     Women's Tops  Banana Republic   49.10  2.108642      0.019003
# 28    Men's Bottoms              Gap    8.51  3.065687      0.030911
# 29      Accessories              Gap    9.58  1.105134      0.008205
# 30     Women's Tops              Gap    6.60  2.050199      0.018322
# 31        Kids Tops              Gap    8.46  2.187792      0.019936
# 32      Accessories  Banana Republic    4.59  1.076812      0.007932
# 33       Denim Shop              Gap   54.80  1.202090      0.009153
# 34  Women's Bottoms              Gap   36.59  2.153984      0.019536
# 35        Kids Tops              Gap    9.46  2.149633      0.019485
# 36       Men's Tops              Gap   49.55  3.005548      0.030125
# 37       Men's Tops  Banana Republic   64.38  2.191056      0.019975
# 38       Men's Tops  Banana Republic    9.08  2.290927      0.021166
# 39        Kids Tops              Gap    5.99  2.005600      0.017805
# 40      Accessories  Banana Republic    3.76  2.143500      0.019413
# 41     Women's Tops  Banana Republic   32.62  2.171481      0.019743
# 42       Denim Shop              Gap   41.50  3.272258      0.033646
# 43        Kids Tops              Gap   16.87  3.134260      0.031813
# 44  Women's Bottoms  Banana Republic   34.54  2.064134      0.018484
# 45     Kids Bottoms              Gap   49.67  3.108531      0.031474
# 46        Kids Tops              Gap    4.80  2.131629      0.019273
# 47       Denim Shop              Gap   33.20  2.154820      0.019546

# %%
products['RetailPrice'] = np.ceil(products.Price)

# %%
products.sample(5)
# Out:
#      ProductID                                     ProductName  Collection  \
# 36  45-570-528  That-Hoodie-You'll-Wear-to-Every-Class Sweater  Men's Tops
# 39  47-230-154                  SpaceX Branded Socks, by NASA™   Kids Tops
# 25  79-411-382  Beautiful Mind Tweed Jacket with Shoulder Pads  Men's Tops
# 21  26-434-264                               Bootleg Boot Cut   Denim Shop
# 35  24-868-681            The Conjuring Graphic Tee Collection   Kids Tops
#
#               Brand  Price   RelFreq  SampleWeight  RetailPrice
# 36              Gap  49.55  3.005548      0.030125         50.0
# 39              Gap   5.99  2.005600      0.017805          6.0
# 25  Banana Republic  73.08  1.011961      0.007317         74.0
# 21              Gap  39.35  2.077511      0.018639         40.0
# 35              Gap   9.46  2.149633      0.019485         10.0

# %% [markdown]
# ## Make Store Data

# %%
stores_va = pd.read_csv('va_stores.txt', header=None, sep=r'\n',engine='python')
stores = stores_va.iloc[::3,0].str.split('located in').str[-1].drop_duplicates().tolist()
stores = [i[1:] for i in stores]

stores_df1 = pd.DataFrame(columns=['StoreName','StoreID'])
stores_df1['StoreName'] = stores
# stores_df1['StoreID'] = '#'+pd.Series(np.random.randint(1000,9999,size=len(stores))).astype(str)+'G'
stores_df1['Location'] = 'VA'
stores_df1['Brand'] = 'Gap'

stores_df1
# Out:
#                           StoreName StoreID Location Brand
# 0    Charlottesville Fashion Square     NaN       VA   Gap
# 1                Dulles Town Center     NaN       VA   Gap
# 2                    Fair Oaks Mall     NaN       VA   Gap
# 3   Fashion Centre at Pentagon City     NaN       VA   Gap
# 4          Leesburg Premium Outlets     NaN       VA   Gap
# 5           Norfolk Premium Outlets     NaN       VA   Gap
# 6                     Potomac Mills     NaN       VA   Gap
# 7            Short Pump Town Center     NaN       VA   Gap
# 8          Stony Point Fashion Park     NaN       VA   Gap
# 9              Tysons Corner Center     NaN       VA   Gap
# 10     Williamsburg Premium Outlets     NaN       VA   Gap

# %%
stores_br = pd.read_csv('stores_br.txt', header=None, sep=r'\n',engine='python')
stores = stores_br.iloc[::2,0].str.split('located in').str[-1].drop_duplicates().tolist()
stores = [i[1:] for i in stores]

stores_df2 = pd.DataFrame(columns=['StoreName','StoreID'])
stores_df2['StoreName'] = stores
# stores_df2['StoreID'] = '#'+pd.Series(np.random.randint(1000,9999,size=len(stores))).astype(str) + 'B'
stores_df2['Location'] = 'VA'
stores_df2['Brand'] = 'Banana Republic'

stores_df2
# Out:
#                           StoreName StoreID Location            Brand
# 0     Barracks Road Shopping Center     NaN       VA  Banana Republic
# 1                Dulles Town Center     NaN       VA  Banana Republic
# 2                    Fair Oaks Mall     NaN       VA  Banana Republic
# 3   Fashion Centre at Pentagon City     NaN       VA  Banana Republic
# 4          Leesburg Premium Outlets     NaN       VA  Banana Republic
# 5                  MacArthur Center     NaN       VA  Banana Republic
# 6           Norfolk Premium Outlets     NaN       VA  Banana Republic
# 7                     Potomac Mills     NaN       VA  Banana Republic
# 8                Reston Town Center     NaN       VA  Banana Republic
# 9            Short Pump Town Center     NaN       VA  Banana Republic
# 10         Stony Point Fashion Park     NaN       VA  Banana Republic
# 11             Tysons Corner Center     NaN       VA  Banana Republic
# 12     Williamsburg Premium Outlets     NaN       VA  Banana Republic

# %%
stores_df = stores_df1.append(stores_df2).reset_index(drop=True)

stores_df['StoreID'] = '#'+pd.Series(np.random.choice(range(1000,9999), 
                                                      size=len(stores_df),
                                                      replace=False)).astype(str) # Generate unique storeIDs

# stores_df['Brand'] = stores_df.Brand.str.replace('Gap','Zap').replace('Banana Republic','Zanana Republic')
stores_df
# Out:
#                           StoreName StoreID Location            Brand
# 0    Charlottesville Fashion Square   #9901       VA              Gap
# 1                Dulles Town Center   #8425       VA              Gap
# 2                    Fair Oaks Mall   #8289       VA              Gap
# 3   Fashion Centre at Pentagon City   #6802       VA              Gap
# 4          Leesburg Premium Outlets   #5101       VA              Gap
# 5           Norfolk Premium Outlets   #7104       VA              Gap
# 6                     Potomac Mills   #9837       VA              Gap
# 7            Short Pump Town Center   #9367       VA              Gap
# 8          Stony Point Fashion Park   #8803       VA              Gap
# 9              Tysons Corner Center   #9981       VA              Gap
# 10     Williamsburg Premium Outlets   #1812       VA              Gap
# 11    Barracks Road Shopping Center   #6569       VA  Banana Republic
# 12               Dulles Town Center   #9033       VA  Banana Republic
# 13                   Fair Oaks Mall   #9543       VA  Banana Republic
# 14  Fashion Centre at Pentagon City   #1047       VA  Banana Republic
# 15         Leesburg Premium Outlets   #9612       VA  Banana Republic
# 16                 MacArthur Center   #6042       VA  Banana Republic
# 17          Norfolk Premium Outlets   #7038       VA  Banana Republic
# 18                    Potomac Mills   #4291       VA  Banana Republic
# 19               Reston Town Center   #8271       VA  Banana Republic
# 20           Short Pump Town Center   #5627       VA  Banana Republic
# 21         Stony Point Fashion Park   #6658       VA  Banana Republic
# 22             Tysons Corner Center   #9112       VA  Banana Republic
# 23     Williamsburg Premium Outlets   #4479       VA  Banana Republic

# %% [markdown]
# ## Create customers

# %%
n_customers = np.random.randint(600,1000)
n_customers
# Out:
# 855

# %%
CustomerIDs = [genStringID(2,chars='ABCDEFHIJKLMNOPQRSTUVWXYZ') + genFloatID(1) for i in range(n_customers)]
CustomerIDs[:5]
# Out:
# ['KD477', 'EP365', 'IV908', 'JX401', 'QM447']

# %% [markdown]
# ## Creating Orders

# %%
n_orders = np.random.randint(2000,2200)
n_orders
# Out:
# 2172

# %%
df_orders =  pd.DataFrame(columns=['OrderID'])
for i in range(n_orders):
    order_i = pd.DataFrame(columns=['OrderID'])
    order_i['OrderID'] = [genStringID(length=7,chars="1234567890QZFSCWZTKRD")]
    #Choose customer 
    order_i['CustomerID'] = np.random.choice(CustomerIDs,size=1)
    # Choose Brand
    brand = np.random.choice(['Gap','Banana Republic'],p=[.4,.6])
    order_i['Brand'] = [brand]
    # Choose corresponding StoreID
    order_i['StoreID'] = np.random.choice(stores_df[stores_df.Brand==brand].StoreID)
    # Choose if Online Order
    order_i['OrderType'] = np.random.choice(a=['InStore', 'HomeDelivery', 'StorePickup'], size=1,
                                            p=[.76,.12,.12] if brand == 'Gap' else [.53,.37,.1])
    
    order_i['ItemSize'] = np.random.choice(a=['XS', 'S', 'M', 'L', 'XL'], size=1,
                                           p=[.1,.24,.32,.24,.1])
    # Give Timestamp
    order_i['Timestamp'] = random_dates(Q1_start, Q1_end, 1)
    
    # Choose number of items in order
#     n_items = np.random.geometric(.4 if brand == 'Gap' else .7)
    order_i['ItemsBought'] = np.random.geometric(.4 if brand == 'Gap' else .7, size=1)
    
    # Add order to existing dataset
    df_orders = df_orders.append(order_i)

# %%
df_orders.reset_index(drop=True,inplace=True)
df_orders.head()
# Out:
#    OrderID CustomerID            Brand StoreID     OrderType ItemSize  \
# 0  DRW7C20      QK848              Gap   #6802       InStore        M
# 1  7T8QZ38      DP336              Gap   #7104       InStore        M
# 2  DR3SRRR      KP441              Gap   #8289  HomeDelivery        S
# 3  4371891      BX487  Banana Republic   #4479       InStore        M
# 4  TD06SWS      CP331  Banana Republic   #9033  HomeDelivery        M
#
#             Timestamp  ItemsBought
# 0 2020-02-11 01:09:56          1.0
# 1 2020-01-13 13:35:27          3.0
# 2 2020-02-01 21:02:14          6.0
# 3 2020-03-08 13:00:49          1.0
# 4 2020-03-26 16:33:04          1.0

# %% [markdown]
# ### Select items per order

# %%
# Create items for each order
df_items = pd.DataFrame()
df_byOrder = df_orders.groupby(by='OrderID')
for orderID, order in df_orders.set_index('OrderID').iterrows():
    productsByBrand = products[products.Brand== order.Brand].copy() # Make sure only choose from products in store
    productsByBrand['SampleWeight'] /= productsByBrand.SampleWeight.sum() # Renormalizes probabilities
    
    n_items = int(order.ItemsBought)
    items = pd.DataFrame()
    items['OrderID'] = [orderID]*n_items
    items['CustomerID'] = [order.CustomerID]*n_items
    items['ProductID'] = np.random.choice(a=productsByBrand.ProductID, 
                                          size=n_items,replace=False,
                                          p=productsByBrand.SampleWeight)
    items['StoreID'] = [order.StoreID]*n_items
    items['OrderType'] = [order.OrderType]*n_items
    items['Timestamp'] = [order.Timestamp]*n_items
    items['Brand'] = [order.Brand]*n_items
    items['ItemSize'] = [order.ItemSize]*n_items
    df_items = df_items.append(items)    

df_items.head()
# Out:
#    OrderID CustomerID   ProductID StoreID     OrderType           Timestamp  \
# 0  DRW7C20      QK848  36-682-186   #6802       InStore 2020-02-11 01:09:56
# 0  7T8QZ38      DP336  60-444-763   #7104       InStore 2020-01-13 13:35:27
# 1  7T8QZ38      DP336  91-951-829   #7104       InStore 2020-01-13 13:35:27
# 2  7T8QZ38      DP336  29-761-664   #7104       InStore 2020-01-13 13:35:27
# 0  DR3SRRR      KP441  64-360-768   #8289  HomeDelivery 2020-02-01 21:02:14
#
#   Brand ItemSize
# 0   Gap        M
# 0   Gap        M
# 1   Gap        M
# 2   Gap        M
# 0   Gap        S

# %% [markdown]
# ### Merge back to store & product data

# %%
df = pd.merge(df_items, products.drop(columns=['Brand','RelFreq','SampleWeight','Price']), 
              how='left', on='ProductID')
df.head()
# Out:
#    OrderID CustomerID   ProductID StoreID     OrderType           Timestamp  \
# 0  DRW7C20      QK848  36-682-186   #6802       InStore 2020-02-11 01:09:56
# 1  7T8QZ38      DP336  60-444-763   #7104       InStore 2020-01-13 13:35:27
# 2  7T8QZ38      DP336  91-951-829   #7104       InStore 2020-01-13 13:35:27
# 3  7T8QZ38      DP336  29-761-664   #7104       InStore 2020-01-13 13:35:27
# 4  DR3SRRR      KP441  64-360-768   #8289  HomeDelivery 2020-02-01 21:02:14
#
#   Brand ItemSize                                        ProductName  \
# 0   Gap        M                                 Adam Levine Choker
# 1   Gap        M  Human Rights (except for the children who make...
# 2   Gap        M        Wrinkled Gray Sweatpants for Work-From-Home
# 3   Gap        M                        Dishwasher-Safe Jean Shorts
# 4   Gap        S                          Lightly Used Boxer Briefs
#
#       Collection  RetailPrice
# 0    Accessories         12.0
# 1      Kids Tops         17.0
# 2  Men's Bottoms          9.0
# 3     Denim Shop         42.0
# 4    Accessories         10.0

# %%
df['Price'] = df.RetailPrice - np.random.choice(a=[.05,.01,.03],
                                                p=[.55,.35,.1],
                                                size=len(df.RetailPrice))
df = df.drop(columns='RetailPrice')
df['ClearanceType'] = df.Price.astype(str).str[-2:].map({'95':'FullRetail',
                                                         '99':'Clearance',
                                                         '97':'FinalSale'})
df.head()
# Out:
#    OrderID CustomerID   ProductID StoreID     OrderType           Timestamp  \
# 0  DRW7C20      QK848  36-682-186   #6802       InStore 2020-02-11 01:09:56
# 1  7T8QZ38      DP336  60-444-763   #7104       InStore 2020-01-13 13:35:27
# 2  7T8QZ38      DP336  91-951-829   #7104       InStore 2020-01-13 13:35:27
# 3  7T8QZ38      DP336  29-761-664   #7104       InStore 2020-01-13 13:35:27
# 4  DR3SRRR      KP441  64-360-768   #8289  HomeDelivery 2020-02-01 21:02:14
#
#   Brand ItemSize                                        ProductName  \
# 0   Gap        M                                 Adam Levine Choker
# 1   Gap        M  Human Rights (except for the children who make...
# 2   Gap        M        Wrinkled Gray Sweatpants for Work-From-Home
# 3   Gap        M                        Dishwasher-Safe Jean Shorts
# 4   Gap        S                          Lightly Used Boxer Briefs
#
#       Collection  Price ClearanceType
# 0    Accessories  11.95    FullRetail
# 1      Kids Tops  16.95    FullRetail
# 2  Men's Bottoms   8.95    FullRetail
# 3     Denim Shop  41.97     FinalSale
# 4    Accessories   9.95    FullRetail

# %%
df = pd.merge(df, stores_df.drop(columns='Brand'), how='left', on='StoreID')
df.head(5)
# Out:
#    OrderID CustomerID   ProductID StoreID     OrderType           Timestamp  \
# 0  DRW7C20      QK848  36-682-186   #6802       InStore 2020-02-11 01:09:56
# 1  7T8QZ38      DP336  60-444-763   #7104       InStore 2020-01-13 13:35:27
# 2  7T8QZ38      DP336  91-951-829   #7104       InStore 2020-01-13 13:35:27
# 3  7T8QZ38      DP336  29-761-664   #7104       InStore 2020-01-13 13:35:27
# 4  DR3SRRR      KP441  64-360-768   #8289  HomeDelivery 2020-02-01 21:02:14
#
#   Brand ItemSize                                        ProductName  \
# 0   Gap        M                                 Adam Levine Choker
# 1   Gap        M  Human Rights (except for the children who make...
# 2   Gap        M        Wrinkled Gray Sweatpants for Work-From-Home
# 3   Gap        M                        Dishwasher-Safe Jean Shorts
# 4   Gap        S                          Lightly Used Boxer Briefs
#
#       Collection  Price ClearanceType                        StoreName  \
# 0    Accessories  11.95    FullRetail  Fashion Centre at Pentagon City
# 1      Kids Tops  16.95    FullRetail          Norfolk Premium Outlets
# 2  Men's Bottoms   8.95    FullRetail          Norfolk Premium Outlets
# 3     Denim Shop  41.97     FinalSale          Norfolk Premium Outlets
# 4    Accessories   9.95    FullRetail                   Fair Oaks Mall
#
#   Location
# 0       VA
# 1       VA
# 2       VA
# 3       VA
# 4       VA

# %% [markdown]
# ## Exploration

# %%
df.shape
# Out:
# (4031, 14)

# %%
df.to_csv('gap.csv',sep='|',index=False)
execution_ct += 1
print('Exported {} times'.format(execution_ct))
# Out:
# Exported 1 times

# %% [markdown]
# ----

# %%
import pandas as pd
import numpy as np
# df2 = pd.read_csv('../gap.csv',sep='|')

# %%
# df2[['StoreID','StoreName','Location']].drop_duplicates().to_csv('gap_stores.csv',sep='|',index=False)

# %%
# df2.drop(columns=['StoreName','Location']).to_csv('gap.csv',sep='|',index=False)
